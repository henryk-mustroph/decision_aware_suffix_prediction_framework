# %%
import importlib
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')
sys.path.insert(0, '../../../../../..')

# Decision labeling runtime models
import data_processing.decision_labeling
importlib.reload(data_processing.decision_labeling)
from data_processing.decision_labeling import DecisionLabeler

# Model
import suffix_pred.models.T_GAN_LSTM
importlib.reload(suffix_pred.models.T_GAN_LSTM)
from suffix_pred.models.T_GAN_LSTM import TaymouriAdversarialLSTM

# Decision-rule guided decoding and reasoning
import suffix_pred.decision_rule_guided_reasoning_inference
importlib.reload(suffix_pred.decision_rule_guided_reasoning_inference)
from suffix_pred.decision_rule_guided_reasoning_inference import DecisionGuidanceConfig, get_decision_guided_evaluator

# Evaluation metrics
import suffix_pred.evalaution.evalaution_metrics
importlib.reload(suffix_pred.evalaution.evalaution_metrics)
from suffix_pred.evalaution.evalaution_metrics import evaluate_dls, dls_per_prefix_length, average_dls

# %%
# Model
# Model clean:
file_path_model = '../../../../../../models/Helpdesk/clean/Helpdesk_T_GAN_LSTM_v1_clean.pkl'

# Model decision_train:
# file_path_model = '../../../../../../models/Helpdesk/decision/Helpdesk_T_GAN_LSTM_v1_DA.pkl'

model = TaymouriAdversarialLSTM.load(file_path_model)

# Load the data: Use for eval always the clean test data:
file_path_test = '../../../../../../data/Helpdesk/tensor_data/normal/helpdesk_all_5_test.pkl'
test_dataset = torch.load(file_path_test, weights_only=False)

# Decision mining artifacts for runtime decision guidance
petri_net_path = '../../../../../../data/Helpdesk/Petri_net/helpdesk.pkl'
decision_bundle_path = '../../../../../../data/Helpdesk/Petri_net/data_aware_Petri_net/decision_places_bundle.json'
decision_model_dir = '../../../../../../data/Helpdesk/Petri_net/data_aware_Petri_net/models'

with open(petri_net_path, 'rb') as f:
    net, im, fm = pickle.load(f)

# Attributes must match decision model
dynamic_attributes = ["Resource",
                      "case_elapsed_time",
                      "event_elapsed_time"]

# Same across the whole trace
static_attributes = ["VariantIndex",
                     "seriousness",
                     "customer",
                     "product",
                     "responsible_section",
                     "seriousness_2",
                     "service_level",
                     "service_type",
                     "support_section",
                     "workgroup"]

decision_labeler = DecisionLabeler(petri_net=(net, im, fm),
                                   decision_model_dir=decision_model_dir,
                                   decision_places_bundle_path=decision_bundle_path,
                                   dynamic_attributes=dynamic_attributes,
                                   static_attributes=static_attributes)

guidance_cfg = DecisionGuidanceConfig(epsilon=1e-3,
                                      beta_max=2.0,
                                      alpha=0.10,
                                      support_threshold=0.05)

print('Model and decision guidance artifacts loaded.')
# Out:
# Model and decision guidance artifacts loaded.

# %%
# Step 1: Guided decode suffixes (beam search with local decision reweighting)
beam_width = 3
mode = 'guided_beam'

guided_beam_eval = get_decision_guided_evaluator(kind='beam',
                                                 model=model,
                                                 dataset=test_dataset,
                                                 decision_labeler=decision_labeler,
                                                 guidance_config=guidance_cfg,
                                                 decision_places_bundle_path=decision_bundle_path,
                                                 concept_name='Activity',
                                                 eos_value='EOS',
                                                 beam_width=beam_width)

guided_beam_outputs = []
guided_beam_reasoning = []

def _default_reasoning_row():
    return {'decision_steps': 0,
            'conflicts': 0,
            'conflict_rate': 0.0,
            'explained_steps': 0,
            'explained_rate': 0.0,
            'trace': []}

def _align_beam_reasonings(decoded_suffixes, reasonings):
    aligned = list(reasonings) if reasonings is not None else []
    needed = len(decoded_suffixes)
    while len(aligned) < needed:
        aligned.append(_default_reasoning_row())
    return aligned[:needed]

for case_id, prefix_len, prefix, target_suffix, decoded_suffixes, reasonings in guided_beam_eval.evaluate(random_order=False, return_reasoning=True):
    guided_beam_outputs.append({'case_id': case_id,
                                'prefix_len': int(prefix_len),
                                'prefix': prefix,
                                'target_suffix': target_suffix,
                                'decoded_suffixes': decoded_suffixes,
                                'mode': mode})

    beam_reasonings = _align_beam_reasonings(decoded_suffixes, reasonings)
    guided_beam_reasoning.append({'case_id': case_id,
                                  'prefix_len': int(prefix_len),
                                  'reasonings': beam_reasonings,
                                  # keep top beam alias for backward compatibility
                                  'reasoning': beam_reasonings[0] if len(beam_reasonings) > 0 else _default_reasoning_row()})

cache_outputs_path = '../../../../../../eval_results/Helpdesk/decision_decoding/helpdesk_t_gan_lstm_decision_guided_outputs.pkl'
cache_reasoning_path = '../../../../../../eval_results/Helpdesk/decision_decoding/helpdesk_t_gan_lstm_decision_guided_reasoning.pkl'

with open(cache_outputs_path, 'wb') as f:
    pickle.dump(guided_beam_outputs, f)

with open(cache_reasoning_path, 'wb') as f:
    pickle.dump(guided_beam_reasoning, f)

print(f"Decoded {len(guided_beam_outputs)} prefix rows in '{mode}'.")

# Step 2: Evaluate DLS from guided decoded outputs
guided_beam_df = evaluate_dls(guided_beam_outputs)
guided_beam_per_prefix = dls_per_prefix_length(guided_beam_df)
guided_beam_avg = average_dls(guided_beam_df)

# Step 3: Aggregate decision and explanation diagnostics across all beams
decision_steps = sum(rr.get('decision_steps', 0)
                    for row in guided_beam_reasoning
                    for rr in row.get('reasonings', []))
conflicts = sum(rr.get('conflicts', 0)
                for row in guided_beam_reasoning
                for rr in row.get('reasonings', []))
explained_steps = sum(rr.get('explained_steps', 0)
                      for row in guided_beam_reasoning
                      for rr in row.get('reasonings', []))

conflict_rate = (conflicts / decision_steps) if decision_steps > 0 else 0.0
explained_rate = (explained_steps / decision_steps) if decision_steps > 0 else 0.0

print(f"Average DLS ({mode}) on full test set: {guided_beam_avg:.4f}")
print(f"Decision steps: {decision_steps} | Conflicts: {conflicts} | Conflict rate: {conflict_rate:.4f}")
print(f"Explained steps: {explained_steps} | Explained rate: {explained_rate:.4f}")
# Out:
#   0%|          | 0/916 [00:00<?, ?it/s]
# Decoded 3343 prefix rows in 'guided_beam'.
# Average DLS (guided_beam) on full test set: 0.9404
# Decision steps: 16245 | Conflicts: 358 | Conflict rate: 0.0220
# Explained steps: 6319 | Explained rate: 0.3890

# %%
# Plot DLS by prefix length for guided beam
plt.figure(figsize=(11, 6))

plt.plot(guided_beam_per_prefix['prefix_len'],
         guided_beam_per_prefix['dls'],
         marker='o',
         label=f"{mode} (avg={guided_beam_avg:.3f})")

plt.title('Helpdesk T-GAN-LSTM: Activity DLS by Prefix Length (guided beam decoding)')
plt.xlabel('Prefix length')
plt.ylabel('Damerau-Levenshtein Similarity (DLS)')
plt.ylim(0.0, 1.0)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

summary = pd.DataFrame({
    'mode': [mode],
    'average_dls': [guided_beam_avg],
    'decision_steps': [decision_steps],
    'conflicts': [conflicts],
    'conflict_rate': [conflict_rate],
    'explained_steps': [explained_steps],
    'explained_rate': [explained_rate],
}).sort_values('average_dls', ascending=False).reset_index(drop=True)
summary
# Out:
#           mode  average_dls  decision_steps  conflicts  conflict_rate  \
# 0  guided_beam     0.940425           16245        358       0.022038
#
#    explained_steps  explained_rate
# 0             6319        0.388981

# %%
# Inspect guided predictions and rule-based reasoning examples with per-attribute checks
with open('../../../../../../eval_results/Helpdesk/decision_decoding/helpdesk_t_gan_lstm_decision_guided_outputs.pkl', 'rb') as f:
    cached_outputs = pickle.load(f)
    
with open('../../../../../../eval_results/Helpdesk/decision_decoding/helpdesk_t_gan_lstm_decision_guided_reasoning.pkl', 'rb') as f:
    cached_reasoning = pickle.load(f)

def _default_reasoning_row():
    return {'decision_steps': 0,
            'conflicts': 0,
            'conflict_rate': 0.0,
            'explained_steps': 0,
            'explained_rate': 0.0,
            'trace': []}

for i in range(min(100, len(cached_outputs))):
    row = cached_outputs[i]
    reason_row = cached_reasoning[i]

    beam_reasonings = reason_row.get('reasonings', [])
    if len(beam_reasonings) == 0 and reason_row.get('reasoning', None) is not None:
        # Backward compatibility with previous cache format.
        beam_reasonings = [reason_row['reasoning']]

    print(f"Case: {row['case_id']}  |  Prefix len: {row['prefix_len']}")
    print(f"  Prefix:            {row['prefix']}")
    print(f"  Target suffix:     {row['target_suffix']}")
    decoded = row['decoded_suffixes']
    print(f"  Predicted beams:   {len(decoded)}")

    for b, beam in enumerate(decoded[:3]):
        reason = beam_reasonings[b] if b < len(beam_reasonings) else _default_reasoning_row()

        print(f"  Beam {b + 1}: {beam}")
        print(f"    Decision steps: {reason['decision_steps']} | Conflicts: {reason['conflicts']} | Conflict rate: {reason['conflict_rate']:.4f}")
        print(f"    Explained steps: {reason.get('explained_steps', 0)} | Explained rate: {reason.get('explained_rate', 0.0):.4f}")

        trace = reason.get('trace', [])
        if len(trace) == 0:
            print("    No supported rule-aligned reasoning step.")
            continue

        for step in trace[:3]:
            decision_top = step.get('decision_top_event')
            decision_top_prob = step.get('decision_top_prob')
            next_event = step['next_event']
            model_prob = step.get('model_prob')
            model_prob_str = f"{model_prob:.1%}" if model_prob is not None else "?"

            if decision_top is not None and decision_top != next_event:
                # Decision model's top pick differs from what the suffix predictor chose
                top_prob_str = f"p={decision_top_prob:.1%}" if decision_top_prob is not None else "p=?"
                print(f"    Decision step {step['step']}: {step['input_event']} -> "
                      f"{decision_top} ({top_prob_str}, decision top) at place {step['place']}, "
                      f"but with prob {model_prob_str} (model), {next_event} was predicted")
            else:
                top_prob_str = f", decision top p={decision_top_prob:.1%}" if decision_top_prob is not None else ""
                print(f"    Decision step {step['step']}: {step['input_event']} -> "
                      f"{next_event} (model prob: {model_prob_str}{top_prob_str}) at place {step['place']}")

            matched_rule = step.get('matched_rule')
            if matched_rule is not None:
                print(f"      Matched rule: {matched_rule.get('rule', '')}")

            attr_checks = step.get('attribute_checks', [])
            seen_attrs = set()
            if len(attr_checks) == 0:
                print("      No attribute checks available.")
            else:
                for chk in attr_checks:
                    attr_name = chk.get('attr', '')
                    attr_value = chk.get('value', None)
                    dedup_key = (attr_name, attr_value)
                    if dedup_key in seen_attrs:
                        continue
                    seen_attrs.add(dedup_key)
                    is_in_rule = bool(chk.get('in_rule_set', False))
                    print(f"      - {attr_name}: value={attr_value} | in_rule_set={is_in_rule}")
    print()
# Out:
# Case: Case 1003  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.6%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.6%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.6%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=76.1%) at place p_16
#       No attribute checks available.
#
# Case: Case 1003  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.6%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.6%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.6%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=76.1%) at place p_16
#       No attribute checks available.
#
# Case: Case 1003  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=76.1%) at place p_16
#       No attribute checks available.
#
# Case: Case 1004  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 27 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 2 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.5%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 27 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 2 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.5%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 2 | Explained rate: 0.6667
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 27 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 2 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.5%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=72.8%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 1, Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 17, Value 18, Value 19, Value 20, Value 3, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9} (+1 more))
#       - customer_prev2: value=Value 27 | in_rule_set=True
#       - Resource_prev3: value=Value 9 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 3 | in_rule_set=True
#
# Case: Case 1004  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.5%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.5%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.5%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=72.8%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 1, Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 17, Value 18, Value 19, Value 20, Value 3, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9} (+1 more))
#       - customer_prev2: value=Value 27 | in_rule_set=True
#       - Resource_prev3: value=Value 9 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 3 | in_rule_set=True
#
# Case: Case 1004  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=72.8%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 1, Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 17, Value 18, Value 19, Value 20, Value 3, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9} (+1 more))
#       - customer_prev2: value=Value 27 | in_rule_set=True
#       - Resource_prev3: value=Value 9 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 3 | in_rule_set=True
#
# Case: Case 1005  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.0%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.0%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.0%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=80.5%) at place p_16
#       No attribute checks available.
#
# Case: Case 1005  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.0%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.0%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.0%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=80.5%) at place p_16
#       No attribute checks available.
#
# Case: Case 1005  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=80.5%) at place p_16
#       No attribute checks available.
#
# Case: Case 1006  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.1%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.1%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.1%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=81.8%) at place p_16
#       No attribute checks available.
#
# Case: Case 1006  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=81.8%) at place p_16
#       No attribute checks available.
#
# Case: Case 1006  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=81.8%) at place p_16
#       No attribute checks available.
#
# Case: Case 1007  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=78.9%) at place p_16
#       No attribute checks available.
#
# Case: Case 1007  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=78.9%) at place p_16
#       No attribute checks available.
#
# Case: Case 1007  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=78.9%) at place p_16
#       No attribute checks available.
#
# Case: Case 1008  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.4%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.4%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.9%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.4%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=82.0%) at place p_16
#       No attribute checks available.
#
# Case: Case 1008  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.4%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.4%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.4%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=82.0%) at place p_16
#       No attribute checks available.
#
# Case: Case 1008  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=82.0%) at place p_16
#       No attribute checks available.
#
# Case: Case 1011  |  Prefix len: 1
#   Prefix:            ['Insert ticket']
#   Target suffix:     ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=66.4%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.3%) at place p_9
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Wait', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Wait -> Resolve ticket (p=40.6%, decision top) at place p_11, but with prob ? (model), Take in charge ticket was predicted
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#
# Case: Case 1011  |  Prefix len: 2
#   Prefix:            ['Insert ticket', 'Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.3%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.3%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.3%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.3%) at place p_16
#       No attribute checks available.
#
# Case: Case 1011  |  Prefix len: 3
#   Prefix:            ['Insert ticket', 'Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.5%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.3%) at place p_16
#       No attribute checks available.
#
# Case: Case 1011  |  Prefix len: 4
#   Prefix:            ['Insert ticket', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.3%) at place p_16
#       No attribute checks available.
#
# Case: Case 1013  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Assign seriousness -> Resolve ticket (model prob: ?, decision top p=98.9%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {5}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more))
#       - customer_prev1: value=Value 18 | in_rule_set=True
#       - VariantIndex_prev1: value=5 | in_rule_set=True
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Assign seriousness -> Resolve ticket (model prob: ?, decision top p=98.9%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {5}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more))
#       - customer_prev1: value=Value 18 | in_rule_set=True
#       - VariantIndex_prev1: value=5 | in_rule_set=True
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 2 | Explained rate: 1.0000
#     Decision step 0: Assign seriousness -> Resolve ticket (model prob: ?, decision top p=98.9%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {5}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more))
#       - customer_prev1: value=Value 18 | in_rule_set=True
#       - VariantIndex_prev1: value=5 | in_rule_set=True
#     Decision step 2: Take in charge ticket -> Wait (p=36.2%, decision top) at place p_16, but with prob ? (model), Resolve ticket was predicted
#       Matched rule: (Resource_prev3 in {Value 1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 18 | in_rule_set=True
#       - Resource_prev3: value=Value 1 | in_rule_set=True
#
# Case: Case 1013  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 1: Take in charge ticket -> Wait (p=36.2%, decision top) at place p_16, but with prob ? (model), Resolve ticket was predicted
#       Matched rule: (Resource_prev3 in {Value 1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 18 | in_rule_set=True
#       - Resource_prev3: value=Value 1 | in_rule_set=True
#
# Case: Case 1016  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 8 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 2 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 8 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 2 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 2 | Explained rate: 0.6667
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=99.0%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 8 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 2 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=81.6%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 1, Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 17, Value 18, Value 19, Value 20, Value 3, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9} (+1 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 8 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 3 | in_rule_set=True
#
# Case: Case 1016  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=97.9%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=81.6%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 1, Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 17, Value 18, Value 19, Value 20, Value 3, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9} (+1 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 8 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 3 | in_rule_set=True
#
# Case: Case 1016  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=81.6%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 1, Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 17, Value 18, Value 19, Value 20, Value 3, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9} (+1 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 8 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 3 | in_rule_set=True
#
# Case: Case 102  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.4%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 62 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 1 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.4%) at place p_9
#       Matched rule: (VariantIndex_prev1 in {1}) AND (customer_prev1 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 138, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 227, Value 27} (+32 more)) AND (service_level_prev_event in {Value 1, Value 2, Value 4})
#       - customer_prev1: value=Value 62 | in_rule_set=True
#       - VariantIndex_prev1: value=1 | in_rule_set=True
#       - service_level_prev_event: value=Value 1 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.8%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 2 | Explained rate: 0.6667
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.4%) at place p_9
# ...
#       - VariantIndex_prev2: value=4 | in_rule_set=True
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.1%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {10, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 19, 2, 20, 22, 23, 24, 26} (+31 more)) AND (VariantIndex_prev1 in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 2, 20, 22} (+32 more)) AND (VariantIndex_prev_event in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 20, 22, 23} (+32 more)) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 14 | in_rule_set=True
#       - VariantIndex_older_last: value=4 | in_rule_set=True
#       - VariantIndex_prev1: value=4 | in_rule_set=True
#       - VariantIndex_prev_event: value=4 | in_rule_set=True
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.9%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {10, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 19, 2, 20, 22, 23, 24, 26} (+31 more)) AND (VariantIndex_prev1 in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 2, 20, 22} (+32 more)) AND (VariantIndex_prev_event in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 20, 22, 23} (+32 more)) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 2 | in_rule_set=True
#       - VariantIndex_older_last: value=4 | in_rule_set=True
#       - VariantIndex_prev1: value=4 | in_rule_set=True
#       - VariantIndex_prev_event: value=4 | in_rule_set=True
#
# Case: Case 1077  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.1%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {10, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 19, 2, 20, 22, 23, 24, 26} (+31 more)) AND (VariantIndex_prev1 in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 2, 20, 22} (+32 more)) AND (VariantIndex_prev_event in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 20, 22, 23} (+32 more)) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 14 | in_rule_set=True
#       - VariantIndex_older_last: value=4 | in_rule_set=True
#       - VariantIndex_prev1: value=4 | in_rule_set=True
#       - VariantIndex_prev_event: value=4 | in_rule_set=True
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.1%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {10, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 19, 2, 20, 22, 23, 24, 26} (+31 more)) AND (VariantIndex_prev1 in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 2, 20, 22} (+32 more)) AND (VariantIndex_prev_event in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 20, 22, 23} (+32 more)) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 14 | in_rule_set=True
#       - VariantIndex_older_last: value=4 | in_rule_set=True
#       - VariantIndex_prev1: value=4 | in_rule_set=True
#       - VariantIndex_prev_event: value=4 | in_rule_set=True
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 2 | Explained rate: 1.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=99.1%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {10, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 19, 2, 20, 22, 23, 24, 26} (+31 more)) AND (VariantIndex_prev1 in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 2, 20, 22} (+32 more)) AND (VariantIndex_prev_event in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 20, 22, 23} (+32 more)) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 14 | in_rule_set=True
#       - VariantIndex_older_last: value=4 | in_rule_set=True
#       - VariantIndex_prev1: value=4 | in_rule_set=True
#       - VariantIndex_prev_event: value=4 | in_rule_set=True
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.9%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {10, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 19, 2, 20, 22, 23, 24, 26} (+31 more)) AND (VariantIndex_prev1 in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 2, 20, 22} (+32 more)) AND (VariantIndex_prev_event in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 20, 22, 23} (+32 more)) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 2 | in_rule_set=True
#       - VariantIndex_older_last: value=4 | in_rule_set=True
#       - VariantIndex_prev1: value=4 | in_rule_set=True
#       - VariantIndex_prev_event: value=4 | in_rule_set=True
#
# Case: Case 1077  |  Prefix len: 4
#   Prefix:            ['Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.9%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {10, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 19, 2, 20, 22, 23, 24, 26} (+31 more)) AND (VariantIndex_prev1 in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 2, 20, 22} (+32 more)) AND (VariantIndex_prev_event in {1, 10, 11, 12, 124, 13, 135, 14, 15, 150, 151, 16, 17, 18, 19, 20, 22, 23} (+32 more)) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more))
#       - customer_prev2: value=Value 8 | in_rule_set=True
#       - Resource_prev3: value=Value 2 | in_rule_set=True
#       - VariantIndex_older_last: value=4 | in_rule_set=True
#       - VariantIndex_prev1: value=4 | in_rule_set=True
#       - VariantIndex_prev_event: value=4 | in_rule_set=True
#
# Case: Case 1082  |  Prefix len: 1
#   Prefix:            ['Assign seriousness']
#   Target suffix:     ['Take in charge ticket', 'Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.8%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.3%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Take in charge ticket', 'Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.8%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.3%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Assign seriousness -> Take in charge ticket (model prob: ?, decision top p=98.8%) at place p_9
#       No attribute checks available.
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.3%) at place p_16
#       No attribute checks available.
#     Decision step 3: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=75.8%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 2})
#       - customer_prev2: value=Value 259 | in_rule_set=True
#       - Resource_prev3: value=Value 13 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 2 | in_rule_set=True
#
# Case: Case 1082  |  Prefix len: 2
#   Prefix:            ['Assign seriousness', 'Take in charge ticket']
#   Target suffix:     ['Resolve ticket', 'Closed']
#   Predicted beams:   3
#   Beam 1: ['Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.3%) at place p_16
#       No attribute checks available.
#   Beam 2: ['Resolve ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.3%) at place p_16
#       No attribute checks available.
#   Beam 3: ['Resolve ticket', 'Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=98.3%) at place p_16
#       No attribute checks available.
#     Decision step 2: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=75.8%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 2})
#       - customer_prev2: value=Value 259 | in_rule_set=True
#       - Resource_prev3: value=Value 13 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 2 | in_rule_set=True
#
# Case: Case 1082  |  Prefix len: 3
#   Prefix:            ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket']
#   Target suffix:     ['Closed']
#   Predicted beams:   3
#   Beam 1: ['Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 2: ['Resolve ticket', 'Closed']
#     Decision steps: 0 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 0 | Explained rate: 0.0000
#     No supported rule-aligned reasoning step.
#   Beam 3: ['Take in charge ticket', 'Resolve ticket', 'Closed']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 1: Take in charge ticket -> Resolve ticket (model prob: ?, decision top p=75.8%) at place p_16
#       Matched rule: (Resource_prev3 in {Value 10, Value 11, Value 12, Value 13, Value 14, Value 15, Value 16, Value 18, Value 19, Value 2, Value 20, Value 4, Value 5, Value 6, Value 7, Value 8, Value 9, __RARE__}) AND (VariantIndex_older_last in {1}) AND (customer_prev2 in {Value 1, Value 100, Value 107, Value 11, Value 113, Value 120, Value 127, Value 13, Value 143, Value 145, Value 146, Value 150, Value 16, Value 17, Value 18, Value 22, Value 227, Value 24} (+31 more)) AND (product_prev_event in {Value 2})
#       - customer_prev2: value=Value 259 | in_rule_set=True
#       - Resource_prev3: value=Value 13 | in_rule_set=True
#       - VariantIndex_older_last: value=1 | in_rule_set=True
#       - product_prev_event: value=Value 2 | in_rule_set=True
