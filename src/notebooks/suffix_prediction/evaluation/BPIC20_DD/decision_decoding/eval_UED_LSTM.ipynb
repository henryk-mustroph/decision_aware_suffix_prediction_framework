# %%
import concurrent
import importlib
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import random
import sys
from tqdm.auto import tqdm

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')
sys.path.insert(0, '../../../../../..')

# Decision labeling runtime models
import data_processing.decision_labeling
importlib.reload(data_processing.decision_labeling)
from data_processing.decision_labeling import DecisionLabeler

# Model
import suffix_pred.models.K_UED_LSTM
importlib.reload(suffix_pred.models.K_UED_LSTM)
from suffix_pred.models.K_UED_LSTM import DropoutUncertaintyEncoderDecoderLSTM

# Decision-rule guided decoding and reasoning
import suffix_pred.decision_rule_guided_reasoning_inference
importlib.reload(suffix_pred.decision_rule_guided_reasoning_inference)
from suffix_pred.decision_rule_guided_reasoning_inference import DecisionGuidanceConfig, get_decision_guided_evaluator

# Evaluation metrics
import suffix_pred.evalaution.evalaution_metrics
importlib.reload(suffix_pred.evalaution.evalaution_metrics)
from suffix_pred.evalaution.evalaution_metrics import evaluate_dls, dls_per_prefix_length, average_dls

# %%
# Model
# Model clean:
file_path_model = '../../../../../../models/BPIC20_DD/clean/BPIC20_DD_UED_LSTM_v1_clean.pkl'

# Model decision_train:
# file_path_model = '../../../../../../models/BPIC20_DD/decision/BPIC20_DD_UED_LSTM_v1_DA.pkl'

model = DropoutUncertaintyEncoderDecoderLSTM.load(file_path_model, dropout=0.1)

# Load the data: Use for eval always the clean test data:
file_path_test = '../../../../../../data/BPIC20_DD/tensor_data/normal/bpic20_dd_all_5_test.pkl'
test_dataset = torch.load(file_path_test, weights_only=False)

# Decision mining artifacts for runtime decision guidance
petri_net_path = '../../../../../../data/BPIC20_DD/Petri_net/bpic20_dd.pkl'
decision_bundle_path = '../../../../../../data/BPIC20_DD/Petri_net/data_aware_Petri_net/decision_places_bundle.json'
decision_model_dir = '../../../../../../data/BPIC20_DD/Petri_net/data_aware_Petri_net/models'

with open(petri_net_path, 'rb') as f:
    net, im, fm = pickle.load(f)

# Attributes must match decision model
dynamic_attributes = ["org:resource",
                          "amount",
                          "budget_status",
                          "revision_count",
                          "supplier_type",
                          "goods_match",
                          "invoice_deviation_pct",
                          "case_elapsed_time",
                          "event_elapsed_time"]

# Same across the whole trace
static_attributes = ["requester_seniority",
                      "department",
                      "category",
                      "priority"]

decision_labeler = DecisionLabeler(petri_net=(net, im, fm),
                                   decision_model_dir=decision_model_dir,
                                   decision_places_bundle_path=decision_bundle_path,
                                   dynamic_attributes=dynamic_attributes,
                                   static_attributes=static_attributes)

guidance_cfg = DecisionGuidanceConfig(epsilon=1e-3,
                                      beta_max=2.0,
                                      alpha=0.10,
                                      support_threshold=0.05)

print('Model and decision guidance artifacts loaded.')
# Out:
# Dynamic data set categories:  ([('concept:name', 10, {'Declaration APPROVED': 1, 'Declaration FINAL_APPROVED': 2, 'Declaration FOR_APPROVAL': 3, 'Declaration REJECTED': 4, 'Declaration SAVED': 5, 'Declaration SUBMITTED': 6, 'EOS': 7, 'Payment Handled': 8, 'Request Payment': 9}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Data set static categories:  ([('case:BudgetNumber', 2, {'budget 86566': 1}), ('case:DeclarationNumber', 6516, {'UNKNOWN': 1, 'declaration number 100001': 2, 'declaration number 100006': 3, 'declaration number 100011': 4, 'declaration number 100016': 5, 'declaration number 100022': 6, 'declaration number 100038': 7, 'declaration number 100043': 8, 'declaration number 100070': 9, 'declaration number 100075': 10, 'declaration number 100080': 11, 'declaration number 100091': 12, 'declaration number 100106': 13, 'declaration number 100112': 14, 'declaration number 100123': 15, 'declaration number 100132': 16, 'declaration number 100138': 17, 'declaration number 100144': 18, 'declaration number 100150': 19, 'declaration number 100161': 20, 'declaration number 100173': 21, 'declaration number 100178': 22, 'declaration number 100188': 23, 'declaration number 100198': 24, 'declaration number 100208': 25, 'declaration number 100214': 26, 'declaration number 100219': 27, 'declaration number 100224': 28, 'declaration number 100229': 29, 'declaration number 100234': 30, 'declaration number 100240': 31, 'declaration number 100246': 32, 'declaration number 100270': 33, 'declaration number 100275': 34, 'declaration number 100290': 35, 'declaration number 100296': 36, 'declaration number 100307': 37, 'declaration number 100312': 38, 'declaration number 100318': 39, 'declaration number 100324': 40, 'declaration number 100334': 41, 'declaration number 100344': 42, 'declaration number 100366': 43, 'declaration number 100375': 44, 'declaration number 100381': 45, 'declaration number 100389': 46, 'declaration number 100400': 47, 'declaration number 100413': 48, 'declaration number 100442': 49, 'declaration number 100453': 50, 'declaration number 100458': 51, 'declaration number 100474': 52, 'declaration number 100480': 53, 'declaration number 100485': 54, 'declaration number 100491': 55, 'declaration number 100497': 56, 'declaration number 100507': 57, 'declaration number 100517': 58, 'declaration number 100522': 59, 'declaration number 100533': 60, 'declaration number 100539': 61, 'declaration number 100554': 62, 'declaration number 100564': 63, 'declaration number 100570': 64, 'declaration number 100575': 65, 'declaration number 100580': 66, 'declaration number 100590': 67, 'declaration number 100600': 68, 'declaration number 100605': 69, 'declaration number 100611': 70, 'declaration number 100617': 71, 'declaration number 100623': 72, 'declaration number 100633': 73, 'declaration number 100638': 74, 'declaration number 100648': 75, 'declaration number 100653': 76, 'declaration number 100658': 77, 'declaration number 100668': 78, 'declaration number 100673': 79, 'declaration number 100678': 80, 'declaration number 100689': 81, 'declaration number 100704': 82, 'declaration number 100709': 83, 'declaration number 100727': 84, 'declaration number 100744': 85, 'declaration number 100754': 86, 'declaration number 100769': 87, 'declaration number 100779': 88, 'declaration number 100785': 89, 'declaration number 100795': 90, 'declaration number 100801': 91, 'declaration number 100806': 92, 'declaration number 100812': 93, 'declaration number 100817': 94, 'declaration number 100830': 95, 'declaration number 100835': 96, 'declaration number 100841': 97, 'declaration number 100846': 98, 'declaration number 100852': 99, 'declaration number 100858': 100, 'declaration number 100864': 101, 'declaration number 100870': 102, 'declaration number 100875': 103, 'declaration number 100888': 104, 'declaration number 100898': 105, 'declaration number 100909': 106, 'declaration number 100914': 107, 'declaration number 100937': 108, 'declaration number 100942': 109, 'declaration number 100955': 110, 'declaration number 100966': 111, 'declaration number 100989': 112, 'declaration number 100995': 113, 'declaration number 101010': 114, 'declaration number 101036': 115, 'declaration number 101054': 116, 'declaration number 101065': 117, 'declaration number 101071': 118, 'd ...
# Encoder dynamic input features:  [['concept:name', 'org:resource', 'org:role'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Encoder static input features:  [['case:BudgetNumber', 'case:DeclarationNumber'], ['case:Amount']]
# Decoder input and output features:  [['concept:name'], []]
# Sequence length of decoder output:  5
#
#
# LSTM cells and FC hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder dynamic:
# Encoder number of labels for each input feature (categorical, numerical): [[10, 4, 9], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input: [[0, 1, 2], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(10, 6)
#   (1): Embedding(4, 3)
#   (2): Embedding(9, 5)
# )
# Total embedding feature size encoder:  14
# Total numerical feature size encoder:  4
# Input feature size encoder:  18
#
#
# Encoder static:
# Encoder number of labels for each input feature (categorical, numerical): [[2, 6516], [1]]
# Encoder indices of tensors in dataset used as input (static): [[0, 1], [0]]
# Static encoder categorical embeddings: ModuleList(
#   (0): Embedding(2, 2)
#   (1): Embedding(6516, 219)
# )
# Total embedding feature size encoder (static):  221
# Total numerical feature size encoder (static):  1
# Static encoder feature size:  222
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [10]
# Decoder label values size for each numerical input feature:  []
# Decoder indices of tensors in dataset used as input:  [[0], []]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(10, 6)
# )
# Total embedding feature size decoder:  6
# Total numerical feature size decoder:  0
# Input feature size decoder:  6
# Output feature list of dicts (featue name, feature output size) of decoder: [{'concept:name': 10}, {}]
# Decoder initialized!
# Model and decision guidance artifacts loaded.

# %%
# Step 1: Guided probabilistic decode suffixes (MC-SA with local decision reweighting)
samples_per_case = 100
worker_count = 32
random_order = False

# Process-local decoder instance for parallel probabilistic inference
_GUIDED_PROB_DECODER = None

def _default_reasoning_row():
    return {'decision_steps': 0,
            'conflicts': 0,
            'conflict_rate': 0.0,
            'explained_steps': 0,
            'explained_rate': 0.0,
            'trace': []}

def _align_sample_reasonings(decoded_suffixes, reasonings):
    aligned = list(reasonings) if reasonings is not None else []
    needed = len(decoded_suffixes)
    while len(aligned) < needed:
        aligned.append(_default_reasoning_row())
    return aligned[:needed]

def _aggregate_prob_reasonings(reasonings):
    if len(reasonings) == 0:
        return _default_reasoning_row()

    decision_steps = sum(r.get('decision_steps', 0) for r in reasonings)
    conflicts = sum(r.get('conflicts', 0) for r in reasonings)
    explained_steps = sum(r.get('explained_steps', 0) for r in reasonings)
    conflict_rate = (conflicts / decision_steps) if decision_steps > 0 else 0.0
    explained_rate = (explained_steps / decision_steps) if decision_steps > 0 else 0.0

    # Keep one representative trace for qualitative inspection
    trace_example = []
    for r in reasonings:
        trace_example = r.get('trace', [])
        if len(trace_example) > 0:
            break

    return {'decision_steps': int(decision_steps),
            'conflicts': int(conflicts),
            'conflict_rate': float(conflict_rate),
            'explained_steps': int(explained_steps),
            'explained_rate': float(explained_rate),
            'trace': trace_example}

def _init_guided_prob_worker(model,
                             dataset,
                             petri_net_path,
                             decision_bundle_path,
                             decision_model_dir,
                             dynamic_attributes,
                             static_attributes,
                             guidance_kwargs,
                             samples_per_case):
    global _GUIDED_PROB_DECODER

    with open(petri_net_path, 'rb') as f:
        net_w, im_w, fm_w = pickle.load(f)

    decision_labeler_w = DecisionLabeler(petri_net=(net_w, im_w, fm_w),
                                         decision_model_dir=decision_model_dir,
                                         decision_places_bundle_path=decision_bundle_path,
                                         dynamic_attributes=dynamic_attributes,
                                         static_attributes=static_attributes)

    guidance_cfg_w = DecisionGuidanceConfig(**guidance_kwargs)

    _GUIDED_PROB_DECODER = get_decision_guided_evaluator(kind='mcsa',
                                                         model=model,
                                                         dataset=dataset,
                                                         decision_labeler=decision_labeler_w,
                                                         guidance_config=guidance_cfg_w,
                                                         decision_places_bundle_path=decision_bundle_path,
                                                         concept_name='concept:name',
                                                         eos_value='EOS',
                                                         samples_per_case=int(samples_per_case),
                                                         sample_argmax=False,
                                                         use_variance_cat=True,
                                                         variational_dropout_sampling=False)

def _collect_guided_prob_case_chunk(case_ids):
    if _GUIDED_PROB_DECODER is None:
        raise RuntimeError('Guided probabilistic worker decoder is not initialized.')

    decoder = _GUIDED_PROB_DECODER
    rows = []
    reason_rows = []

    for case_id in case_ids:
        full_case = decoder.cases.get(case_id)
        if full_case is None:
            continue

        for prefix_len, prefix, zero_mask, statics, suffix in decoder._iterate_case(full_case):
            prefix_activity = decoder._decode_activity_prefix(prefix)
            target_suffix = decoder._decode_activity_suffix(suffix)

            sampled_suffixes = []
            reasonings = []

            for _ in range(decoder.samples_per_case):
                sampled, reasoning = decoder.sample_suffix(prefix=prefix,
                                                          prefix_len=prefix_len,
                                                          static_inputs=statics,
                                                          mask=zero_mask,
                                                          suffix=suffix,
                                                          include_model_states=False,
                                                          return_reasoning=True)
                sampled_suffixes.append(sampled)
                reasonings.append(reasoning)

            aligned_reasonings = _align_sample_reasonings(sampled_suffixes, reasonings)

            rows.append({'case_id': case_id,
                         'prefix_len': int(prefix_len),
                         'prefix': prefix_activity,
                         'target_suffix': target_suffix,
                         'decoded_suffixes': sampled_suffixes,
                         'mode': 'guided_probabilistic'})

            reason_rows.append({'case_id': case_id,
                                'prefix_len': int(prefix_len),
                                # Keep every sampled reasoning (1:1 with sampled_suffixes).
                                'reasonings': aligned_reasonings,
                                # Keep aggregate alias for backward compatibility.
                                'reasoning': _aggregate_prob_reasonings(aligned_reasonings)})

    return rows, reason_rows

# Build a local decoder once to enumerate case ids
guided_prob_eval = get_decision_guided_evaluator(kind='mcsa',
                                                 model=model,
                                                 dataset=test_dataset,
                                                 decision_labeler=decision_labeler,
                                                 guidance_config=guidance_cfg,
                                                 decision_places_bundle_path=decision_bundle_path,
                                                 concept_name='concept:name',
                                                 eos_value='EOS',
                                                 samples_per_case=samples_per_case,
                                                 sample_argmax=False,
                                                 use_variance_cat=True,
                                                 variational_dropout_sampling=False)

case_ids = list(guided_prob_eval.cases.keys())
if random_order:
    random.shuffle(case_ids)

guided_prob_outputs = []
guided_prob_reasoning = []

if worker_count <= 1 or len(case_ids) <= 1:
    for case_id in tqdm(case_ids, desc='Guided probabilistic inference cases'):
        full_case = guided_prob_eval.cases.get(case_id)
        if full_case is None:
            continue

        for prefix_len, prefix, zero_mask, statics, suffix in guided_prob_eval._iterate_case(full_case):
            prefix_activity = guided_prob_eval._decode_activity_prefix(prefix)
            target_suffix = guided_prob_eval._decode_activity_suffix(suffix)

            sampled_suffixes = []
            reasonings = []

            for _ in range(guided_prob_eval.samples_per_case):
                sampled, reasoning = guided_prob_eval.sample_suffix(prefix=prefix,
                                                                   prefix_len=prefix_len,
                                                                   static_inputs=statics,
                                                                   mask=zero_mask,
                                                                   suffix=suffix,
                                                                   include_model_states=False,
                                                                   return_reasoning=True)
                sampled_suffixes.append(sampled)
                reasonings.append(reasoning)

            aligned_reasonings = _align_sample_reasonings(sampled_suffixes, reasonings)

            guided_prob_outputs.append({'case_id': case_id,
                                        'prefix_len': int(prefix_len),
                                        'prefix': prefix_activity,
                                        'target_suffix': target_suffix,
                                        'decoded_suffixes': sampled_suffixes,
                                        'mode': 'guided_probabilistic'})

            guided_prob_reasoning.append({'case_id': case_id,
                                          'prefix_len': int(prefix_len),
                                          'reasonings': aligned_reasonings,
                                          'reasoning': _aggregate_prob_reasonings(aligned_reasonings)})
else:
    chunk_size = max(1, (len(case_ids) + worker_count - 1) // worker_count)
    case_chunks = [case_ids[i:i + chunk_size] for i in range(0, len(case_ids), chunk_size)]

    guidance_kwargs = {'epsilon': 1e-3, 'beta_max': 2.0, 'alpha': 0.10, 'support_threshold': 0.05}

    with concurrent.futures.ProcessPoolExecutor(
        max_workers=worker_count,
        initializer=_init_guided_prob_worker,
        initargs=(model,
                  test_dataset,
                  petri_net_path,
                  decision_bundle_path,
                  decision_model_dir,
                  dynamic_attributes,
                  static_attributes,
                  guidance_kwargs,
                  samples_per_case),
    ) as executor:
        chunk_futures = [(i, executor.submit(_collect_guided_prob_case_chunk, chunk))
                         for i, chunk in enumerate(case_chunks)]
        pending = {f: i for i, f in chunk_futures}
        chunk_results = {}
        for future in tqdm(concurrent.futures.as_completed(pending), total=len(pending), desc='Guided probabilistic inference chunks'):
            chunk_results[pending[future]] = future.result()

    # Reassemble in original submission order so rows match C-LSTM / T-GAN case order
    for i in range(len(case_chunks)):
        chunk_outputs, chunk_reasoning = chunk_results[i]
        guided_prob_outputs.extend(chunk_outputs)
        guided_prob_reasoning.extend(chunk_reasoning)

cache_outputs_path = '../../../../../../eval_results/BPIC20_DD/decision_decoding/bpic20_dd_ued_lstm_decision_guided_outputs.pkl'
cache_reasoning_path = '../../../../../../eval_results/BPIC20_DD/decision_decoding/bpic20_dd_ued_lstm_decision_guided_reasoning.pkl'

with open(cache_outputs_path, 'wb') as f:
    pickle.dump(guided_prob_outputs, f)

with open(cache_reasoning_path, 'wb') as f:
    pickle.dump(guided_prob_reasoning, f)

print(f"Decoded {len(guided_prob_outputs)} prefix rows in 'guided_probabilistic'.")

# Step 2: Evaluate DLS from guided decoded outputs
guided_prob_df = evaluate_dls(guided_prob_outputs, probabilistic_reduction='mean', parallel_scoring=True, num_processes=worker_count)
guided_prob_per_prefix = dls_per_prefix_length(guided_prob_df)
guided_prob_avg = average_dls(guided_prob_df)
guided_prob_min = float(guided_prob_df['dls_min'].mean())
guided_prob_max = float(guided_prob_df['dls_max'].mean())

# Step 3: Aggregate decision and explanation diagnostics across all samples
decision_steps = sum(rr.get('decision_steps', 0)
                    for row in guided_prob_reasoning
                    for rr in row.get('reasonings', []))
conflicts = sum(rr.get('conflicts', 0)
                for row in guided_prob_reasoning
                for rr in row.get('reasonings', []))
explained_steps = sum(rr.get('explained_steps', 0)
                      for row in guided_prob_reasoning
                      for rr in row.get('reasonings', []))

conflict_rate = (conflicts / decision_steps) if decision_steps > 0 else 0.0
explained_rate = (explained_steps / decision_steps) if decision_steps > 0 else 0.0

print(f"Average DLS (guided_probabilistic, mean over T samples): {guided_prob_avg:.4f}")
print(f"Average DLS min (guided_probabilistic): {guided_prob_min:.4f}")
print(f"Average DLS max (guided_probabilistic): {guided_prob_max:.4f}")
print(f"Decision steps: {decision_steps} | Conflicts: {conflicts} | Conflict rate: {conflict_rate:.4f}")
print(f"Explained steps: {explained_steps} | Explained rate: {explained_rate:.4f}")
# Out:
# Guided probabilistic inference chunks:   0%|          | 0/32 [00:00<?, ?it/s]
# Decoded 9124 prefix rows in 'guided_probabilistic'.
# Average DLS (guided_probabilistic, mean over T samples): 0.8695
# Average DLS min (guided_probabilistic): 0.4685
# Average DLS max (guided_probabilistic): 0.9920
# Decision steps: 2942376 | Conflicts: 11596 | Conflict rate: 0.0039
# Explained steps: 920193 | Explained rate: 0.3127

# %%
# Plot DLS by prefix length for guided probabilistic decoding
plt.figure(figsize=(11, 6))

plt.plot(guided_prob_per_prefix['prefix_len'],
         guided_prob_per_prefix['dls'],
         marker='o',
         label=f"guided_probabilistic mean (avg={guided_prob_avg:.3f})")

if {'dls_min', 'dls_max'}.issubset(guided_prob_per_prefix.columns):
    plt.fill_between(guided_prob_per_prefix['prefix_len'],
                     guided_prob_per_prefix['dls_min'],
                     guided_prob_per_prefix['dls_max'],
                     alpha=0.2,
                     label='guided_probabilistic min-max range')

plt.title('BPIC20_DD K-UED-LSTM: Activity DLS by Prefix Length (guided probabilistic decoding)')
plt.xlabel('Prefix length')
plt.ylabel('Damerau-Levenshtein Similarity (DLS)')
plt.ylim(0.0, 1.0)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

summary = pd.DataFrame({
    'mode': ['guided_probabilistic'],
    'average_dls': [guided_prob_avg],
    'average_dls_min': [guided_prob_min],
    'average_dls_max': [guided_prob_max],
    'decision_steps': [decision_steps],
    'conflicts': [conflicts],
    'conflict_rate': [conflict_rate],
    'explained_steps': [explained_steps],
    'explained_rate': [explained_rate],
}).sort_values('average_dls', ascending=False).reset_index(drop=True)
summary
# Out:
#                    mode  average_dls  average_dls_min  average_dls_max  \
# 0  guided_probabilistic     0.869518         0.468481         0.991983
#
#    decision_steps  conflicts  conflict_rate  explained_steps  explained_rate
# 0         2942376      11596       0.003941           920193        0.312738

# %%
# Inspect guided probabilistic predictions and rule-based reasoning examples
with open('../../../../../../eval_results/BPIC20_DD/decision_decoding/bpic20_dd_ued_lstm_decision_guided_outputs.pkl', 'rb') as f:
    cached_outputs = pickle.load(f)
    
with open('../../../../../../eval_results/BPIC20_DD/decision_decoding/bpic20_dd_ued_lstm_decision_guided_reasoning.pkl', 'rb') as f:
    cached_reasoning = pickle.load(f)

def _default_reasoning_row():
    return {'decision_steps': 0,
            'conflicts': 0,
            'conflict_rate': 0.0,
            'explained_steps': 0,
            'explained_rate': 0.0,
            'trace': []}

for i in range(min(100, len(cached_outputs))):
    row = cached_outputs[i]
    reason_row = cached_reasoning[i]

    sample_reasonings = reason_row.get('reasonings', [])
    if len(sample_reasonings) == 0 and reason_row.get('reasoning', None) is not None:
        # Backward compatibility with previous cache format.
        sample_reasonings = [reason_row['reasoning']]

    print(f"Case: {row['case_id']}  |  Prefix len: {row['prefix_len']}")
    print(f"  Prefix:            {row['prefix']}")
    print(f"  Target suffix:     {row['target_suffix']}")
    decoded = row['decoded_suffixes']
    print(f"  Sampled suffixes:  {len(decoded)}")

    for j, sample in enumerate(decoded[:3]):
        reason = sample_reasonings[j] if j < len(sample_reasonings) else _default_reasoning_row()

        print(f"  Sample {j}: {sample}")
        print(f"    Decision steps: {reason['decision_steps']} | Conflicts: {reason['conflicts']} | Conflict rate: {reason['conflict_rate']:.4f}")
        print(f"    Explained steps: {reason.get('explained_steps', 0)} | Explained rate: {reason.get('explained_rate', 0.0):.4f}")

        trace = reason.get('trace', [])
        if len(trace) == 0:
            print("    No supported rule-aligned reasoning step.")
            continue

        for step in trace[:3]:
            decision_top = step.get('decision_top_event')
            decision_top_prob = step.get('decision_top_prob')
            next_event = step['next_event']
            model_prob = step.get('model_prob')
            model_prob_str = f"{model_prob:.1%}" if model_prob is not None else "?"

            if decision_top is not None and decision_top != next_event:
                # Decision model's top pick differs from what the suffix predictor chose
                top_prob_str = f"p={decision_top_prob:.1%}" if decision_top_prob is not None else "p=?"
                print(f"    Decision step {step['step']}: {step['input_event']} -> "
                      f"{decision_top} ({top_prob_str}, decision top) at place {step['place']}, "
                      f"but with prob {model_prob_str} (model), {next_event} was predicted")
            else:
                top_prob_str = f", decision top p={decision_top_prob:.1%}" if decision_top_prob is not None else ""
                print(f"    Decision step {step['step']}: {step['input_event']} -> "
                      f"{next_event} (model prob: {model_prob_str}{top_prob_str}) at place {step['place']}")

            matched_rule = step.get('matched_rule')
            if matched_rule is not None:
                print(f"      Matched rule: {matched_rule.get('rule', '')}")

            attr_checks = step.get('attribute_checks', [])
            seen_attrs = set()
            if len(attr_checks) == 0:
                print("      No attribute checks available.")
            else:
                for chk in attr_checks:
                    attr_name = chk.get('attr', '')
                    attr_value = chk.get('value', None)
                    dedup_key = (attr_name, attr_value)
                    if dedup_key in seen_attrs:
                        continue
                    seen_attrs.add(dedup_key)
                    is_in_rule = bool(chk.get('in_rule_set', False))
                    print(f"      - {attr_name}: value={attr_value} | in_rule_set={is_in_rule}")
    print()
# Out:
# Case: declaration 100027  |  Prefix len: 1
#   Prefix:            ['Declaration SUBMITTED']
#   Target suffix:     ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration REJECTED', 'Declaration REJECTED', 'Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 7 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.1429
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (model prob: 18.9%, decision top p=64.4%) at place p_15
#       No attribute checks available.
#     Decision step 1: Declaration REJECTED -> Declaration REJECTED (model prob: 99.3%, decision top p=66.4%) at place p_7
#       No attribute checks available.
#     Decision step 2: Declaration REJECTED -> Declaration REJECTED (p=57.0%, decision top) at place p_7, but with prob 87.0% (model), Declaration SUBMITTED was predicted
#       No attribute checks available.
#   Sample 1: ['Declaration REJECTED', 'Declaration REJECTED', 'Declaration SUBMITTED', 'Declaration REJECTED', 'Declaration REJECTED', 'Declaration SUBMITTED', 'Declaration REJECTED', 'Declaration REJECTED', 'Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 13 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.0769
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (model prob: 17.7%, decision top p=64.4%) at place p_15
#       No attribute checks available.
#     Decision step 1: Declaration REJECTED -> Declaration REJECTED (model prob: 99.2%, decision top p=66.4%) at place p_7
#       No attribute checks available.
#     Decision step 2: Declaration REJECTED -> Declaration REJECTED (p=57.0%, decision top) at place p_7, but with prob 86.9% (model), Declaration SUBMITTED was predicted
#       No attribute checks available.
#   Sample 2: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 83.5% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 88.6%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 88.3%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#
# Case: declaration 100027  |  Prefix len: 2
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED']
#   Target suffix:     ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 92.6%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 98.3%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#   Sample 1: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 97.6%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.7%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 98.6%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.8%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#
# Case: declaration 100027  |  Prefix len: 3
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED']
#   Target suffix:     ['Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#   Sample 1: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#   Sample 2: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#
# Case: declaration 100027  |  Prefix len: 4
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment']
#   Target suffix:     ['Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#   Sample 1: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#   Sample 2: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5114478468894958 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.09036567310492198 | in_rule_set=True
#
# Case: declaration 100032  |  Prefix len: 1
#   Prefix:            ['Declaration SUBMITTED']
#   Target suffix:     ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 81.0% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 88.0%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 88.2%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 1: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Declaration SUBMITTED', 'Declaration REJECTED', 'Declaration REJECTED', 'Declaration REJECTED']
#     Decision steps: 7 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.1429
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 77.4% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 91.9%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 90.9%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 2: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 58.5% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 91.1%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 89.6%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#
# Case: declaration 100032  |  Prefix len: 2
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED']
#   Target suffix:     ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 90.7%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.1%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#   Sample 1: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 95.9%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.2%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 96.2%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.2%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#
# Case: declaration 100032  |  Prefix len: 3
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED']
#   Target suffix:     ['Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#   Sample 1: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#   Sample 2: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#
# Case: declaration 100032  |  Prefix len: 4
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment']
#   Target suffix:     ['Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#   Sample 1: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#   Sample 2: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121185183525085 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2734042505423228 | in_rule_set=True
#
# Case: declaration 100059  |  Prefix len: 1
#   Prefix:            ['Declaration SUBMITTED']
#   Target suffix:     ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 1.4% (model), Declaration FINAL_APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 98.4%, decision top p=55.6%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.0 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2560802102088928 | in_rule_set=True
#   Sample 1: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 81.6% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 91.0%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 82.4%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 2: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 74.3% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 91.5%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 86.7%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#
# Case: declaration 100059  |  Prefix len: 2
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED']
#   Target suffix:     ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 96.4%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.6%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#   Sample 1: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 97.7%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.7%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 96.7%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.6%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#
# Case: declaration 100059  |  Prefix len: 3
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED']
#   Target suffix:     ['Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#   Sample 1: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#   Sample 2: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#
# Case: declaration 100059  |  Prefix len: 4
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment']
#   Target suffix:     ['Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#   Sample 1: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#   Sample 2: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5121604204177856 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.1648204419761896 | in_rule_set=True
#
# Case: declaration 100085  |  Prefix len: 1
#   Prefix:            ['Declaration SUBMITTED']
#   Target suffix:     ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 76.8% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 84.6%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 87.6%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 1: ['Declaration APPROVED', 'Declaration REJECTED', 'Declaration REJECTED', 'Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 8 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.1250
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 79.8% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (p=60.5%, decision top) at place p_27, but with prob 5.7% (model), Declaration REJECTED was predicted
#       No attribute checks available.
#     Decision step 2: Declaration REJECTED -> Declaration REJECTED (model prob: 50.8%, decision top p=57.0%) at place p_7
#       No attribute checks available.
#   Sample 2: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 72.1% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 89.2%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 88.5%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#
# Case: declaration 100085  |  Prefix len: 2
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED']
#   Target suffix:     ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 99.1%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.8%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#   Sample 1: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 94.4%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.1%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 87.6%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 98.2%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#
# Case: declaration 100085  |  Prefix len: 3
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED']
#   Target suffix:     ['Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#   Sample 1: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#   Sample 2: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#
# Case: declaration 100085  |  Prefix len: 4
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment']
#   Target suffix:     ['Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#   Sample 1: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#   Sample 2: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5117589235305786 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.16846916684880853 | in_rule_set=True
#
# Case: declaration 100116  |  Prefix len: 1
#   Prefix:            ['Declaration SUBMITTED']
#   Target suffix:     ['Declaration APPROVED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 80.5% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 85.2%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 88.6%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 1: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 79.1% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 90.3%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 88.9%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 2: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Declaration SUBMITTED', 'Declaration REJECTED', 'Declaration REJECTED']
#     Decision steps: 6 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.1667
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 81.0% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 88.7%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 91.1%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#
# Case: declaration 100116  |  Prefix len: 2
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED']
#   Target suffix:     ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 87.2%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 98.7%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5118074417114258 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2794714868068695 | in_rule_set=True
#   Sample 1: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (p=60.5%, decision top) at place p_27, but with prob 4.2% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 98.9%, decision top p=61.1%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 97.3%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 86.9%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 98.3%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5118074417114258 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2794714868068695 | in_rule_set=True
#
# Case: declaration 100116  |  Prefix len: 3
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration APPROVED']
#   Target suffix:     ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 99.6%, decision top p=61.1%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.32660701870918274 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.28938908874988556 | in_rule_set=True
#   Sample 1: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 99.6%, decision top p=61.1%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.32660701870918274 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.28938908874988556 | in_rule_set=True
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 99.6%, decision top p=61.1%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.32660701870918274 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.28938908874988556 | in_rule_set=True
#
# Case: declaration 100116  |  Prefix len: 4
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED']
#   Target suffix:     ['Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.32660701870918274 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.28938908874988556 | in_rule_set=True
#   Sample 1: ['Request Payment', 'Payment Handled']
# ...
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#   Sample 1: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 99.5%, decision top p=61.1%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.8%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 99.6%, decision top p=61.1%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.8%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#
# Case: declaration 100547  |  Prefix len: 4
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED']
#   Target suffix:     ['Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#   Sample 1: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#   Sample 2: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=50.5%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#
# Case: declaration 100547  |  Prefix len: 5
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment']
#   Target suffix:     ['Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#   Sample 1: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#   Sample 2: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=0.17170006036758423 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.2009802684187889 | in_rule_set=True
#
# Case: declaration 100584  |  Prefix len: 1
#   Prefix:            ['Declaration SUBMITTED']
#   Target suffix:     ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 80.0% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 86.8%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 89.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 1: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Payment Handled']
#     Decision steps: 4 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.2500
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 82.9% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 87.6%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 87.6%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#   Sample 2: ['Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 6 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 2 | Explained rate: 0.3333
#     Decision step 0: Declaration SUBMITTED -> Declaration REJECTED (p=64.4%, decision top) at place p_15, but with prob 82.9% (model), Declaration APPROVED was predicted
#       No attribute checks available.
#     Decision step 1: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 91.1%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 2: Declaration FINAL_APPROVED -> Request Payment (model prob: 89.6%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#
# Case: declaration 100584  |  Prefix len: 2
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED']
#   Target suffix:     ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 99.0%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.8%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#   Sample 1: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled']
#     Decision steps: 3 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.3333
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 95.7%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.4%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#   Sample 2: ['Declaration FINAL_APPROVED', 'Request Payment', 'Payment Handled', 'Declaration SUBMITTED', 'Declaration REJECTED', 'Declaration REJECTED', 'Declaration SUBMITTED', 'Declaration REJECTED', 'Declaration REJECTED', 'Declaration REJECTED']
#     Decision steps: 9 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.1111
#     Decision step 0: Declaration APPROVED -> Declaration FINAL_APPROVED (model prob: 98.9%, decision top p=60.5%) at place p_27
#       No attribute checks available.
#     Decision step 1: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.8%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 2: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#
# Case: declaration 100584  |  Prefix len: 3
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED']
#   Target suffix:     ['Request Payment', 'Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 99.9%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#   Sample 1: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#   Sample 2: ['Request Payment', 'Payment Handled']
#     Decision steps: 2 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 0.5000
#     Decision step 0: Declaration FINAL_APPROVED -> Request Payment (model prob: 100.0%, decision top p=49.8%) at place p_22
#       No attribute checks available.
#     Decision step 1: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#
# Case: declaration 100584  |  Prefix len: 4
#   Prefix:            ['Declaration SUBMITTED', 'Declaration APPROVED', 'Declaration FINAL_APPROVED', 'Request Payment']
#   Target suffix:     ['Payment Handled']
#   Sampled suffixes:  100
#   Sample 0: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#   Sample 1: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
#   Sample 2: ['Payment Handled']
#     Decision steps: 1 | Conflicts: 0 | Conflict rate: 0.0000
#     Explained steps: 1 | Explained rate: 1.0000
#     Decision step 0: Request Payment -> Payment Handled (model prob: 100.0%, decision top p=93.6%) at place p_29
#       Matched rule: (event_elapsed_time_older_mean <= 32.5) AND (event_elapsed_time_prev3 <= 0.5)
#       - event_elapsed_time_prev3: value=-0.5116684436798096 | in_rule_set=True
#       - event_elapsed_time_older_mean: value=-0.3338825007279714 | in_rule_set=True
