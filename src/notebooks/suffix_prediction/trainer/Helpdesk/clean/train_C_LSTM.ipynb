# %%
import importlib
import sys

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')
sys.path.insert(0, '../../../../../..')

# %%
# Load the data
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../data/Helpdesk/tensor_data/normal/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../data/Helpdesk/tensor_data/normal/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)

# %%
# Helpdesk dataset dynamic categories, features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
# print(helpdesk_all_categories_cat)
helpdesk_all_categories_num = helpdesk_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
helpdesk_all_stat_categories = helpdesk_train_dataset.all_static_categories

helpdesk_all_stat_categories_cat = helpdesk_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
helpdesk_all_stat_categories_num = helpdesk_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(helpdesk_all_stat_categories_cat):
     print(f"Helpdesk static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_stat_categories_num):
     print(f"Helpdesk static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
# Out:
# Helpdesk dynamic categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk amount of category labels: 15
# Helpdesk dynamic categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk amount of category labels: 24
#
#
# Helpdesk dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# Helpdesk amount of numerical: 1
#
#
# Helpdesk static categorical feature: VariantIndex, Index position in categorical data list: 0
# Helpdesk amount of category labels: 175
# Helpdesk static categorical feature: seriousness, Index position in categorical data list: 1
# Helpdesk amount of category labels: 2
# Helpdesk static categorical feature: customer, Index position in categorical data list: 2
# Helpdesk amount of category labels: 359
# Helpdesk static categorical feature: product, Index position in categorical data list: 3
# Helpdesk amount of category labels: 22
# Helpdesk static categorical feature: responsible_section, Index position in categorical data list: 4
# Helpdesk amount of category labels: 8
# Helpdesk static categorical feature: seriousness_2, Index position in categorical data list: 5
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_level, Index position in categorical data list: 6
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_type, Index position in categorical data list: 7
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: support_section, Index position in categorical data list: 8
# Helpdesk amount of category labels: 7
# Helpdesk static categorical feature: workgroup, Index position in categorical data list: 9
# Helpdesk amount of category labels: 5

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)

# Encoder features (fixed): use only requested features
enc_feat_cat = ['Activity', 'Resource']
enc_feat_num = ['case_elapsed_time']
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Decoder features (unused by C-LSTM training cell, kept for consistency)
dec_feat_cat = ['Activity']
dec_feat_num = []
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time']]
# Features decoder:  [['Activity'], []]

# %%
import suffix_pred.models.C_LSTM
importlib.reload(suffix_pred.models.C_LSTM)
from suffix_pred.models.C_LSTM import FullShared_Join_LSTM

# Size hidden layer
hidden_size = 50

# Number of LSTM cells
num_layers = 1

# STANDARD: One numerical output to predict
input_size = 1

# C-LSTM uses dynamic prefix features only
model_feat = enc_feat

# Output size: activity classes only
activity_feature_name = 'Activity'
activity_feature_index = next(i for i, cat in enumerate(helpdesk_all_categories_cat) if cat[0] == activity_feature_name)
output_size_act = helpdesk_all_categories_cat[activity_feature_index][1]

# C-LSTM model initialization
model = FullShared_Join_LSTM(data_set_categories=helpdesk_all_categories,
                             hidden_size=hidden_size,
                             num_layers=num_layers,
                             model_feat=model_feat,
                             input_size=input_size,
                             output_size_act=output_size_act)
# Out:
# Data set categories:  ([('Activity', 15, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'EOS': 4, 'INVALID': 5, 'Insert ticket': 6, 'RESOLVED': 7, 'Require upgrade': 8, 'Resolve SW anomaly': 9, 'Resolve ticket': 10, 'Schedule intervention': 11, 'Take in charge ticket': 12, 'VERIFIED': 13, 'Wait': 14}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Model input features:  [['Activity', 'Resource'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(15, 7)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size:  16
# Input feature size:  17
# Cells hidden size:  50
# Number of LSTM layer:  1
# /home/PSPLab/.local/share/virtualenvs/decision_aware_augmentation_for_PPM-0DzgvVpC/lib/python3.12/site-packages/torch/nn/modules/rnn.py:990: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)

# %%
import suffix_pred.loss
importlib.reload(suffix_pred.loss)
from suffix_pred.loss import Loss

loss_obj = Loss()

# %%
import suffix_pred.train
importlib.reload(suffix_pred.train)
from suffix_pred.train import CTraining

from torch.optim.lr_scheduler import ReduceLROnPlateau

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Start learning rate
learning_rate = 0.001
weight_decay = 0.0

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15, min_lr=1e-8)


# Keep consistent across all models
# Epochs / Batch size
num_epochs = 100
batch_size = 128

# Shuffle data
shuffle = True

optimize_values = {"optimizer": optimizer,
                   "scheduler": scheduler,
                   "epochs": num_epochs,
                   "mini_batches": batch_size,
                   "shuffle": shuffle}

# Activity feature index and EOS id for activity-only next-event prediction
activity_feature_name = 'Activity'
concept_name_id = next(i for i, cat in enumerate(helpdesk_all_categories_cat) if cat[0] == activity_feature_name)
activity_label_to_id = helpdesk_all_categories_cat[concept_name_id][2]
eos_id = activity_label_to_id.get('EOS')

model_output_path = "../../../../../../models/Helpdesk/clean/Helpdesk_C_LSTM_v1_clean.pkl"
os.makedirs(os.path.dirname(model_output_path), exist_ok=True)

trainer = CTraining(device=device,
                    model=model,
                    data_train=helpdesk_train_dataset,
                    data_val=helpdesk_val_dataset,
                    optimize_values=optimize_values,
                    concept_name_id=concept_name_id,
                    eos_id=eos_id,
                    loss_obj=loss_obj,
                    save_model_n_th_epoch=1,
                    saving_path=model_output_path)

# Train the model (activity sequence modeling via next-activity training)
trainer.train()
# Out:
# Device: cuda
# Device:  cuda
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0.0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7faefbf4ce00>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.8963
# Validation: Avg Validation Loss: 0.3261
# Validation Loss for Scheduler: 0.3261
# saving model
# Epoch [2/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.3577
# Validation: Avg Validation Loss: 0.2338
# Validation Loss for Scheduler: 0.2338
# saving model
# Epoch [3/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2967
# Validation: Avg Validation Loss: 0.2116
# Validation Loss for Scheduler: 0.2116
# saving model
# Epoch [4/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2764
# Validation: Avg Validation Loss: 0.2072
# Validation Loss for Scheduler: 0.2072
# saving model
# Epoch [5/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2551
# Validation: Avg Validation Loss: 0.1899
# Validation Loss for Scheduler: 0.1899
# saving model
# Epoch [6/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2489
# Validation: Avg Validation Loss: 0.1918
# Validation Loss for Scheduler: 0.1918
# saving model
# Epoch [7/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2377
# Validation: Avg Validation Loss: 0.1957
# Validation Loss for Scheduler: 0.1957
# saving model
# Epoch [8/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2291
# Validation: Avg Validation Loss: 0.1735
# Validation Loss for Scheduler: 0.1735
# saving model
# Epoch [9/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2127
# Validation: Avg Validation Loss: 0.1865
# Validation Loss for Scheduler: 0.1865
# saving model
# Epoch [10/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2079
# Validation: Avg Validation Loss: 0.1832
# Validation Loss for Scheduler: 0.1832
# saving model
# Epoch [11/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.2000
# Validation: Avg Validation Loss: 0.1956
# Validation Loss for Scheduler: 0.1956
# saving model
# Epoch [12/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1930
# Validation: Avg Validation Loss: 0.1820
# Validation Loss for Scheduler: 0.1820
# saving model
# Epoch [13/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1875
# Validation: Avg Validation Loss: 0.1785
# Validation Loss for Scheduler: 0.1785
# saving model
# Epoch [14/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1782
# Validation: Avg Validation Loss: 0.1809
# Validation Loss for Scheduler: 0.1809
# saving model
# Epoch [15/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1653
# Validation: Avg Validation Loss: 0.1849
# Validation Loss for Scheduler: 0.1849
# saving model
# Epoch [16/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1601
# Validation: Avg Validation Loss: 0.1953
# Validation Loss for Scheduler: 0.1953
# saving model
# Epoch [17/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1496
# Validation: Avg Validation Loss: 0.1749
# Validation Loss for Scheduler: 0.1749
# saving model
# Epoch [18/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1419
# Validation: Avg Validation Loss: 0.1796
# Validation Loss for Scheduler: 0.1796
# saving model
# Epoch [19/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1358
# Validation: Avg Validation Loss: 0.1886
# Validation Loss for Scheduler: 0.1886
# saving model
# Epoch [20/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1321
# Validation: Avg Validation Loss: 0.1652
# Validation Loss for Scheduler: 0.1652
# saving model
# Epoch [21/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1233
# Validation: Avg Validation Loss: 0.1962
# Validation Loss for Scheduler: 0.1962
# saving model
# Epoch [22/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1147
# Validation: Avg Validation Loss: 0.1775
# Validation Loss for Scheduler: 0.1775
# saving model
# Epoch [23/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1141
# Validation: Avg Validation Loss: 0.2117
# Validation Loss for Scheduler: 0.2117
# saving model
# Epoch [24/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.1025
# Validation: Avg Validation Loss: 0.1818
# Validation Loss for Scheduler: 0.1818
# saving model
# Epoch [25/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0944
# Validation: Avg Validation Loss: 0.1863
# Validation Loss for Scheduler: 0.1863
# saving model
# Epoch [26/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0914
# Validation: Avg Validation Loss: 0.2025
# Validation Loss for Scheduler: 0.2025
# saving model
# Epoch [27/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0903
# Validation: Avg Validation Loss: 0.1971
# Validation Loss for Scheduler: 0.1971
# saving model
# Epoch [28/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0845
# Validation: Avg Validation Loss: 0.2100
# Validation Loss for Scheduler: 0.2100
# saving model
# Epoch [29/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0768
# Validation: Avg Validation Loss: 0.2195
# Validation Loss for Scheduler: 0.2195
# saving model
# Epoch [30/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0708
# Validation: Avg Validation Loss: 0.2103
# Validation Loss for Scheduler: 0.2103
# saving model
# Epoch [31/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0746
# Validation: Avg Validation Loss: 0.2060
# Validation Loss for Scheduler: 0.2060
# saving model
# Epoch [32/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0684
# Validation: Avg Validation Loss: 0.2303
# Validation Loss for Scheduler: 0.2303
# saving model
# Epoch [33/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0622
# Validation: Avg Validation Loss: 0.2237
# Validation Loss for Scheduler: 0.2237
# saving model
# Epoch [34/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0587
# Validation: Avg Validation Loss: 0.2392
# Validation Loss for Scheduler: 0.2392
# saving model
# Epoch [35/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0558
# Validation: Avg Validation Loss: 0.2197
# Validation Loss for Scheduler: 0.2197
# saving model
# Epoch [36/100], Learning Rate: 0.001
# Training: Avg Attenuated Training Loss: 0.0535
# Validation: Avg Validation Loss: 0.2440
# Validation Loss for Scheduler: 0.2440
# saving model
# Epoch [37/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0464
# Validation: Avg Validation Loss: 0.2405
# Validation Loss for Scheduler: 0.2405
# saving model
# Epoch [38/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0433
# Validation: Avg Validation Loss: 0.2444
# Validation Loss for Scheduler: 0.2444
# saving model
# Epoch [39/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0423
# Validation: Avg Validation Loss: 0.2438
# Validation Loss for Scheduler: 0.2438
# saving model
# Epoch [40/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0404
# Validation: Avg Validation Loss: 0.2438
# Validation Loss for Scheduler: 0.2438
# saving model
# Epoch [41/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0387
# Validation: Avg Validation Loss: 0.2462
# Validation Loss for Scheduler: 0.2462
# saving model
# Epoch [42/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0423
# Validation: Avg Validation Loss: 0.2419
# Validation Loss for Scheduler: 0.2419
# saving model
# Epoch [43/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0393
# Validation: Avg Validation Loss: 0.2485
# Validation Loss for Scheduler: 0.2485
# saving model
# Epoch [44/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0370
# Validation: Avg Validation Loss: 0.2248
# Validation Loss for Scheduler: 0.2248
# saving model
# Epoch [45/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0360
# Validation: Avg Validation Loss: 0.2295
# Validation Loss for Scheduler: 0.2295
# saving model
# Epoch [46/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0361
# Validation: Avg Validation Loss: 0.2534
# Validation Loss for Scheduler: 0.2534
# saving model
# Epoch [47/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0370
# Validation: Avg Validation Loss: 0.2291
# Validation Loss for Scheduler: 0.2291
# saving model
# Epoch [48/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0367
# Validation: Avg Validation Loss: 0.2619
# Validation Loss for Scheduler: 0.2619
# saving model
# Epoch [49/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0360
# Validation: Avg Validation Loss: 0.2404
# Validation Loss for Scheduler: 0.2404
# saving model
# Epoch [50/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0343
# Validation: Avg Validation Loss: 0.2284
# Validation Loss for Scheduler: 0.2284
# saving model
# Epoch [51/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0366
# Validation: Avg Validation Loss: 0.2258
# Validation Loss for Scheduler: 0.2258
# saving model
# Epoch [52/100], Learning Rate: 0.0001
# Training: Avg Attenuated Training Loss: 0.0343
# Validation: Avg Validation Loss: 0.2351
# Validation Loss for Scheduler: 0.2351
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0345
# Validation: Avg Validation Loss: 0.2384
# Validation Loss for Scheduler: 0.2384
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0343
# Validation: Avg Validation Loss: 0.2325
# Validation Loss for Scheduler: 0.2325
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0334
# Validation: Avg Validation Loss: 0.2462
# Validation Loss for Scheduler: 0.2462
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0331
# Validation: Avg Validation Loss: 0.2391
# Validation Loss for Scheduler: 0.2391
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0328
# Validation: Avg Validation Loss: 0.2623
# Validation Loss for Scheduler: 0.2623
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0333
# Validation: Avg Validation Loss: 0.2422
# Validation Loss for Scheduler: 0.2422
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0325
# Validation: Avg Validation Loss: 0.2400
# Validation Loss for Scheduler: 0.2400
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0345
# Validation: Avg Validation Loss: 0.2411
# Validation Loss for Scheduler: 0.2411
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0340
# Validation: Avg Validation Loss: 0.2396
# Validation Loss for Scheduler: 0.2396
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0327
# Validation: Avg Validation Loss: 0.2434
# Validation Loss for Scheduler: 0.2434
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0340
# Validation: Avg Validation Loss: 0.2240
# Validation Loss for Scheduler: 0.2240
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0318
# Validation: Avg Validation Loss: 0.2338
# Validation Loss for Scheduler: 0.2338
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0331
# Validation: Avg Validation Loss: 0.2302
# Validation Loss for Scheduler: 0.2302
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0327
# Validation: Avg Validation Loss: 0.2405
# Validation Loss for Scheduler: 0.2405
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0340
# Validation: Avg Validation Loss: 0.2315
# Validation Loss for Scheduler: 0.2315
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.0341
# Validation: Avg Validation Loss: 0.2349
# Validation Loss for Scheduler: 0.2349
# saving model
# Epoch [69/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0327
# Validation: Avg Validation Loss: 0.2465
# Validation Loss for Scheduler: 0.2465
# saving model
# Epoch [70/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0329
# Validation: Avg Validation Loss: 0.2538
# Validation Loss for Scheduler: 0.2538
# saving model
# Epoch [71/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0317
# Validation: Avg Validation Loss: 0.2572
# Validation Loss for Scheduler: 0.2572
# saving model
# Epoch [72/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0324
# Validation: Avg Validation Loss: 0.2530
# Validation Loss for Scheduler: 0.2530
# saving model
# Epoch [73/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0316
# Validation: Avg Validation Loss: 0.2292
# Validation Loss for Scheduler: 0.2292
# saving model
# Epoch [74/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0322
# Validation: Avg Validation Loss: 0.2336
# Validation Loss for Scheduler: 0.2336
# saving model
# Epoch [75/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0315
# Validation: Avg Validation Loss: 0.2323
# Validation Loss for Scheduler: 0.2323
# saving model
# Epoch [76/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0317
# Validation: Avg Validation Loss: 0.2428
# Validation Loss for Scheduler: 0.2428
# saving model
# Epoch [77/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0330
# Validation: Avg Validation Loss: 0.2567
# Validation Loss for Scheduler: 0.2567
# saving model
# Epoch [78/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0324
# Validation: Avg Validation Loss: 0.2548
# Validation Loss for Scheduler: 0.2548
# saving model
# Epoch [79/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0328
# Validation: Avg Validation Loss: 0.2385
# Validation Loss for Scheduler: 0.2385
# saving model
# Epoch [80/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0326
# Validation: Avg Validation Loss: 0.2423
# Validation Loss for Scheduler: 0.2423
# saving model
# Epoch [81/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0325
# Validation: Avg Validation Loss: 0.2455
# Validation Loss for Scheduler: 0.2455
# saving model
# Epoch [82/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0342
# Validation: Avg Validation Loss: 0.2447
# Validation Loss for Scheduler: 0.2447
# saving model
# Epoch [83/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0327
# Validation: Avg Validation Loss: 0.2344
# Validation Loss for Scheduler: 0.2344
# saving model
# Epoch [84/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 0.0334
# Validation: Avg Validation Loss: 0.2671
# Validation Loss for Scheduler: 0.2671
# saving model
# Epoch [85/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0327
# Validation: Avg Validation Loss: 0.2350
# Validation Loss for Scheduler: 0.2350
# saving model
# Epoch [86/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0320
# Validation: Avg Validation Loss: 0.2359
# Validation Loss for Scheduler: 0.2359
# saving model
# Epoch [87/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0321
# Validation: Avg Validation Loss: 0.2405
# Validation Loss for Scheduler: 0.2405
# saving model
# Epoch [88/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0328
# Validation: Avg Validation Loss: 0.2477
# Validation Loss for Scheduler: 0.2477
# saving model
# Epoch [89/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0317
# Validation: Avg Validation Loss: 0.2638
# Validation Loss for Scheduler: 0.2638
# saving model
# Epoch [90/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0321
# Validation: Avg Validation Loss: 0.2229
# Validation Loss for Scheduler: 0.2229
# saving model
# Epoch [91/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0333
# Validation: Avg Validation Loss: 0.2481
# Validation Loss for Scheduler: 0.2481
# saving model
# Epoch [92/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0335
# Validation: Avg Validation Loss: 0.2373
# Validation Loss for Scheduler: 0.2373
# saving model
# Epoch [93/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0326
# Validation: Avg Validation Loss: 0.2311
# Validation Loss for Scheduler: 0.2311
# saving model
# Epoch [94/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0329
# Validation: Avg Validation Loss: 0.2446
# Validation Loss for Scheduler: 0.2446
# saving model
# Epoch [95/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0340
# Validation: Avg Validation Loss: 0.2374
# Validation Loss for Scheduler: 0.2374
# saving model
# Epoch [96/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0339
# Validation: Avg Validation Loss: 0.2238
# Validation Loss for Scheduler: 0.2238
# saving model
# Epoch [97/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0333
# Validation: Avg Validation Loss: 0.2356
# Validation Loss for Scheduler: 0.2356
# saving model
# Epoch [98/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0332
# Validation: Avg Validation Loss: 0.2530
# Validation Loss for Scheduler: 0.2530
# saving model
# Epoch [99/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0327
# Validation: Avg Validation Loss: 0.2334
# Validation Loss for Scheduler: 0.2334
# saving model
# Epoch [100/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 0.0315
# Validation: Avg Validation Loss: 0.2414
# Validation Loss for Scheduler: 0.2414
# saving model
# Training complete.
# Model saved to path: ../../../../../../models/Helpdesk/clean/Helpdesk_C_LSTM_v1_clean.pkl
# ([0.896273556789127,
#   0.35772038374198684,
#   0.296689992992703,
#   0.27636142105821077,
#   0.25513326307895395,
#   0.24887431870906726,
#   0.23770089284303264,
#   0.22912878473075704,
#   0.21270101218390355,
#   0.20794553692888365,
#   0.19999271742316013,
#   0.1929686880422705,
#   0.18746772668230424,
#   0.17819473253340895,
#   0.1653363307630387,
#   0.16010544758392584,
#   0.14962680747202778,
#   0.14193987636186114,
#   0.13582853156082128,
#   0.1321378413741605,
#   0.12331391806893666,
#   0.11474024330974993,
#   0.11406325168241191,
#   0.10252954957818766,
#   0.09441436583671821,
#   0.0913869938257774,
#   0.09027434180601748,
#   0.08454390325574973,
#   0.07683767950153747,
#   0.07078832366563585,
#   0.07464653603869294,
#   0.06835699311047451,
#   0.06216399525420381,
#   0.05867508624721993,
#   0.055801673243334945,
#   0.05354704275308604,
#   0.046438977888084675,
#   0.04334923029592081,
#   0.042262879155422435,
#   0.040423269471187795,
#   0.03871215274023456,
#   0.04229772503492038,
#   0.03927064226478885,
#   0.036975600801562085,
#   0.035985182049051954,
#   0.036108412035450406,
#   0.03701745721067242,
#   0.03673594441145248,
#   0.035991535966344385,
#   0.03425678231757681,
#   0.03664012696730708,
#   0.034341571541767944,
#   0.03451277641793115,
#   0.03434567369516392,
#   0.03344552690022275,
#   0.033131078154771426,
#   0.032794416149428816,
#   0.033309990871236275,
#   0.03251871803707076,
#   0.034547703744365124,
#   0.0339812377976134,
#   0.03274822006762506,
#   0.03403191263103909,
#   0.03177039992222306,
#   0.03309225172836146,
#   0.03272853994959914,
#   0.03403989619302025,
#   0.03412887187025279,
#   0.0327405553746866,
#   0.03286541364723902,
#   0.031740977524976254,
#   0.03241649533060183,
#   0.031593342584562104,
#   0.03224069358986042,
#   0.03148840572321873,
#   0.03172759864897971,
#   0.033002623348334516,
#   0.03238690693952451,
#   0.03281358272315712,
#   0.03264579008794774,
#   0.03250267453504504,
#   0.034170267510723426,
#   0.03273963915833503,
#   0.03337097144258473,
#   0.032736439532344015,
#   0.032006317006270275,
#   0.032058993076751814,
#   0.0327710757563916,
#   0.031674497890064,
#   0.03210640132721992,
#   0.03328004319524102,
#   0.033500575097363205,
#   0.03263187362521955,
#   0.03288279723914323,
#   0.03404008889241879,
#   0.03394244738252099,
#   0.03325032784577903,
#   0.03323804751495668,
#   0.03267501235657602,
#   0.031491589548766886],
#  [0.3260547724366188,
#   0.2338074388412329,
#   0.21160600014030934,
#   0.20719675421714784,
#   0.18987043316547686,
#   0.19178152203559876,
#   0.19565347641706465,
#   0.17349634997546673,
#   0.1865308113539448,
#   0.18319784276760542,
#   0.19555757366120816,
#   0.181962134459844,
#   0.1785013096779585,
#   0.18091765716671943,
#   0.18492057222872973,
#   0.195261487737298,
#   0.17492224246066493,
#   0.1796302440791176,
#   0.18858456183224917,
#   0.1651969391386956,
#   0.19623137621853787,
#   0.17750023784957683,
#   0.2117101314663887,
#   0.18184183068716755,
#   0.18629987329244613,
#   0.2025323248282075,
#   0.19708487030118704,
#   0.2099569692648947,
#   0.21951668236691219,
#   0.2103006476894594,
#   0.20596912814304233,
#   0.2303134113496456,
#   0.22365211556461873,
#   0.23922150690108537,
#   0.2197382932063192,
#   0.24400147756561638,
#   0.24046443205756637,
#   0.24441129300743342,
#   0.24383831396698952,
#   0.24381959594813032,
#   0.24616500150877982,
#   0.2418700867239386,
#   0.24848488848656416,
#   0.2247636022243219,
#   0.2295125382952392,
#   0.2533575681876391,
#   0.2291370312217623,
#   0.2618762365030125,
#   0.24036784626543523,
#   0.22835999410073363,
#   0.22584483897886598,
#   0.23514987739830617,
#   0.23838568611357075,
#   0.23247843265533447,
#   0.24623338300555658,
#   0.2390740781184286,
#   0.26226566559993303,
#   0.2422006184794009,
#   0.23999464014531652,
#   0.24114444246515632,
#   0.23961197772475246,
#   0.24337788236040908,
#   0.22399626694655475,
#   0.23382094061002134,
#   0.2302418566402048,
#   0.2404849252281845,
#   0.2315005545783788,
#   0.23494168544188143,
#   0.24645291889086365,
#   0.253773319539614,
#   0.25716495083644986,
#   0.252959078354761,
#   0.22924004316938898,
#   0.23356524339644238,
#   0.23234319251030683,
#   0.24276952570304275,
#   0.2566886625936604,
#   0.2547507421206683,
#   0.23850844676892918,
#   0.24225969977676867,
#   0.2454547233087942,
#   0.24469241223190552,
#   0.23436029712991932,
#   0.2670652320422232,
#   0.23495231493591115,
#   0.23586664819875017,
#   0.24046615578234196,
#   0.24769375597126783,
#   0.26376629784703254,
#   0.22289604703053975,
#   0.24811691934242844,
#   0.23733819011365995,
#   0.23109429989619037,
#   0.24460260085761548,
#   0.23737740471959115,
#   0.22381266820244491,
#   0.23563720310106873,
#   0.2529902694094926,
#   0.23343937372108206,
#   0.2413842696439063])
