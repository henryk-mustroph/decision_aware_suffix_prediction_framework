# %%
import importlib
import sys
import numpy as np
from collections import Counter
import pandas as pd

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')
sys.path.insert(0, '../../../../../..')

# %%
# Load the data
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../data/Helpdesk/tensor_data/normal/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../data/Helpdesk/tensor_data/normal/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)

# %%
# Helpdesk dataset dynamic categories, features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
# print(helpdesk_all_categories_cat)
helpdesk_all_categories_num = helpdesk_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
helpdesk_all_stat_categories = helpdesk_train_dataset.all_static_categories

helpdesk_all_stat_categories_cat = helpdesk_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
helpdesk_all_stat_categories_num = helpdesk_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(helpdesk_all_stat_categories_cat):
     print(f"Helpdesk static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_stat_categories_num):
     print(f"Helpdesk static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
# Out:
# Helpdesk dynamic categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk amount of category labels: 15
# Helpdesk dynamic categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk amount of category labels: 24
#
#
# Helpdesk dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# Helpdesk amount of numerical: 1
#
#
# Helpdesk static categorical feature: VariantIndex, Index position in categorical data list: 0
# Helpdesk amount of category labels: 175
# Helpdesk static categorical feature: seriousness, Index position in categorical data list: 1
# Helpdesk amount of category labels: 2
# Helpdesk static categorical feature: customer, Index position in categorical data list: 2
# Helpdesk amount of category labels: 359
# Helpdesk static categorical feature: product, Index position in categorical data list: 3
# Helpdesk amount of category labels: 22
# Helpdesk static categorical feature: responsible_section, Index position in categorical data list: 4
# Helpdesk amount of category labels: 8
# Helpdesk static categorical feature: seriousness_2, Index position in categorical data list: 5
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_level, Index position in categorical data list: 6
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_type, Index position in categorical data list: 7
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: support_section, Index position in categorical data list: 8
# Helpdesk amount of category labels: 7
# Helpdesk static categorical feature: workgroup, Index position in categorical data list: 9
# Helpdesk amount of category labels: 5

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)

# Encoder features (fixed): use only requested features
enc_feat_cat = ['Activity', 'Resource']
enc_feat_num = ['case_elapsed_time']
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Decoder features (unused by C-LSTM training cell, kept for consistency)
dec_feat_cat = ['Activity']
dec_feat_num = []
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time']]
# Features decoder:  [['Activity'], []]

# %%
import suffix_pred.models.C_LSTM
importlib.reload(suffix_pred.models.C_LSTM)
from suffix_pred.models.C_LSTM import FullShared_Join_LSTM

# Size hidden layer
hidden_size = 50

# Number of LSTM cells
num_layers = 1

# STANDARD: One numerical output to predict
input_size = 1

# C-LSTM uses dynamic prefix features only
model_feat = enc_feat

# Output size: activity classes only
activity_feature_name = 'Activity'
activity_feature_index = next(i for i, cat in enumerate(helpdesk_all_categories_cat) if cat[0] == activity_feature_name)
output_size_act = helpdesk_all_categories_cat[activity_feature_index][1]

# C-LSTM model initialization
model = FullShared_Join_LSTM(data_set_categories=helpdesk_all_categories,
                             hidden_size=hidden_size,
                             num_layers=num_layers,
                             model_feat=model_feat,
                             input_size=input_size,
                             output_size_act=output_size_act)
# Out:
# Data set categories:  ([('Activity', 15, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'EOS': 4, 'INVALID': 5, 'Insert ticket': 6, 'RESOLVED': 7, 'Require upgrade': 8, 'Resolve SW anomaly': 9, 'Resolve ticket': 10, 'Schedule intervention': 11, 'Take in charge ticket': 12, 'VERIFIED': 13, 'Wait': 14}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Model input features:  [['Activity', 'Resource'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(15, 7)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size:  16
# Input feature size:  17
# Cells hidden size:  50
# Number of LSTM layer:  1
# /home/PSPLab/.local/share/virtualenvs/decision_aware_augmentation_for_PPM-0DzgvVpC/lib/python3.12/site-packages/torch/nn/modules/rnn.py:990: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)

# %%
import suffix_pred.loss
importlib.reload(suffix_pred.loss)
from suffix_pred.loss import Loss

loss_obj = Loss()

# %%
import suffix_pred.train
importlib.reload(suffix_pred.train)
from suffix_pred.train import CTraining

from torch.optim.lr_scheduler import ReduceLROnPlateau

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Start learning rate
learning_rate = 1e-5
weight_decay = 0.0

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15, min_lr=1e-8)

# Epochs / Batch size
num_epochs = 100
batch_size = 128

# Shuffle data
shuffle = True

optimize_values = {"optimizer": optimizer,
                   "scheduler": scheduler,
                   "epochs": num_epochs,
                   "mini_batches": batch_size,
                   "shuffle": shuffle}

# Activity feature index and EOS id for activity-only next-event prediction
activity_feature_name = 'Activity'
concept_name_id = next(i for i, cat in enumerate(helpdesk_all_categories_cat) if cat[0] == activity_feature_name)
activity_label_to_id = helpdesk_all_categories_cat[concept_name_id][2]
eos_id = activity_label_to_id.get('EOS')

model_output_path = "../../../../../../models/Helpdesk/clean/Helpdesk_C_LSTM_v1_clean.pkl"
os.makedirs(os.path.dirname(model_output_path), exist_ok=True)

trainer = CTraining(device=device,
                    model=model,
                    data_train=helpdesk_train_dataset,
                    data_val=helpdesk_val_dataset,
                    optimize_values=optimize_values,
                    concept_name_id=concept_name_id,
                    eos_id=eos_id,
                    loss_obj=loss_obj,
                    save_model_n_th_epoch=1,
                    saving_path=model_output_path)

# Train the model (activity sequence modeling via next-activity training)
trainer.train()
# Out:
# Device: cuda
# Device:  cuda
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0.0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7fef3891c4a0>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7274
# Validation: Avg Validation Loss: 2.6686
# Validation Loss for Scheduler: 2.6686
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.6314
# Validation: Avg Validation Loss: 2.4712
# Validation Loss for Scheduler: 2.4712
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.5376
# Validation: Avg Validation Loss: 2.4727
# Validation Loss for Scheduler: 2.4727
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.4412
# Validation: Avg Validation Loss: 2.3741
# Validation Loss for Scheduler: 2.3741
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3403
# Validation: Avg Validation Loss: 2.2695
# Validation Loss for Scheduler: 2.2695
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2466
# Validation: Avg Validation Loss: 2.0807
# Validation Loss for Scheduler: 2.0807
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1439
# Validation: Avg Validation Loss: 2.0541
# Validation Loss for Scheduler: 2.0541
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0393
# Validation: Avg Validation Loss: 1.9558
# Validation Loss for Scheduler: 1.9558
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9342
# Validation: Avg Validation Loss: 1.7689
# Validation Loss for Scheduler: 1.7689
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.8240
# Validation: Avg Validation Loss: 1.7354
# Validation Loss for Scheduler: 1.7354
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.7218
# Validation: Avg Validation Loss: 1.6375
# Validation Loss for Scheduler: 1.6375
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.6266
# Validation: Avg Validation Loss: 1.4705
# Validation Loss for Scheduler: 1.4705
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.5321
# Validation: Avg Validation Loss: 1.4362
# Validation Loss for Scheduler: 1.4362
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.4590
# Validation: Avg Validation Loss: 1.3227
# Validation Loss for Scheduler: 1.3227
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.3757
# Validation: Avg Validation Loss: 1.2905
# Validation Loss for Scheduler: 1.2905
# saving model
# Epoch [16/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.3080
# Validation: Avg Validation Loss: 1.2184
# Validation Loss for Scheduler: 1.2184
# saving model
# Epoch [17/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.2589
# Validation: Avg Validation Loss: 1.1629
# Validation Loss for Scheduler: 1.1629
# saving model
# Epoch [18/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.1988
# Validation: Avg Validation Loss: 1.1268
# Validation Loss for Scheduler: 1.1268
# saving model
# Epoch [19/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.1534
# Validation: Avg Validation Loss: 1.0808
# Validation Loss for Scheduler: 1.0808
# saving model
# Epoch [20/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.1161
# Validation: Avg Validation Loss: 1.0221
# Validation Loss for Scheduler: 1.0221
# saving model
# Epoch [21/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.0817
# Validation: Avg Validation Loss: 1.0071
# Validation Loss for Scheduler: 1.0071
# saving model
# Epoch [22/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.0472
# Validation: Avg Validation Loss: 0.9824
# Validation Loss for Scheduler: 0.9824
# saving model
# Epoch [23/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.0122
# Validation: Avg Validation Loss: 0.9438
# Validation Loss for Scheduler: 0.9438
# saving model
# Epoch [24/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9842
# Validation: Avg Validation Loss: 0.9236
# Validation Loss for Scheduler: 0.9236
# saving model
# Epoch [25/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9667
# Validation: Avg Validation Loss: 0.8562
# Validation Loss for Scheduler: 0.8562
# saving model
# Epoch [26/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9401
# Validation: Avg Validation Loss: 0.8351
# Validation Loss for Scheduler: 0.8351
# saving model
# Epoch [27/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9168
# Validation: Avg Validation Loss: 0.8478
# Validation Loss for Scheduler: 0.8478
# saving model
# Epoch [28/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8980
# Validation: Avg Validation Loss: 0.8141
# Validation Loss for Scheduler: 0.8141
# saving model
# Epoch [29/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8825
# Validation: Avg Validation Loss: 0.7794
# Validation Loss for Scheduler: 0.7794
# saving model
# Epoch [30/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8577
# Validation: Avg Validation Loss: 0.7856
# Validation Loss for Scheduler: 0.7856
# saving model
# Epoch [31/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8506
# Validation: Avg Validation Loss: 0.7614
# Validation Loss for Scheduler: 0.7614
# saving model
# Epoch [32/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8213
# Validation: Avg Validation Loss: 0.7693
# Validation Loss for Scheduler: 0.7693
# saving model
# Epoch [33/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8027
# Validation: Avg Validation Loss: 0.7210
# Validation Loss for Scheduler: 0.7210
# saving model
# Epoch [34/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7915
# Validation: Avg Validation Loss: 0.7426
# Validation Loss for Scheduler: 0.7426
# saving model
# Epoch [35/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7815
# Validation: Avg Validation Loss: 0.7108
# Validation Loss for Scheduler: 0.7108
# saving model
# Epoch [36/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7613
# Validation: Avg Validation Loss: 0.7181
# Validation Loss for Scheduler: 0.7181
# saving model
# Epoch [37/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7457
# Validation: Avg Validation Loss: 0.6948
# Validation Loss for Scheduler: 0.6948
# saving model
# Epoch [38/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7394
# Validation: Avg Validation Loss: 0.6437
# Validation Loss for Scheduler: 0.6437
# saving model
# Epoch [39/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7203
# Validation: Avg Validation Loss: 0.6366
# Validation Loss for Scheduler: 0.6366
# saving model
# Epoch [40/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7019
# Validation: Avg Validation Loss: 0.6576
# Validation Loss for Scheduler: 0.6576
# saving model
# Epoch [41/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7048
# Validation: Avg Validation Loss: 0.6318
# Validation Loss for Scheduler: 0.6318
# saving model
# Epoch [42/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6820
# Validation: Avg Validation Loss: 0.6259
# Validation Loss for Scheduler: 0.6259
# saving model
# Epoch [43/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6810
# Validation: Avg Validation Loss: 0.6273
# Validation Loss for Scheduler: 0.6273
# saving model
# Epoch [44/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6725
# Validation: Avg Validation Loss: 0.6255
# Validation Loss for Scheduler: 0.6255
# saving model
# Epoch [45/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6544
# Validation: Avg Validation Loss: 0.5882
# Validation Loss for Scheduler: 0.5882
# saving model
# Epoch [46/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6387
# Validation: Avg Validation Loss: 0.5657
# Validation Loss for Scheduler: 0.5657
# saving model
# Epoch [47/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6359
# Validation: Avg Validation Loss: 0.5802
# Validation Loss for Scheduler: 0.5802
# saving model
# Epoch [48/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6181
# Validation: Avg Validation Loss: 0.5425
# Validation Loss for Scheduler: 0.5425
# saving model
# Epoch [49/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6101
# Validation: Avg Validation Loss: 0.5542
# Validation Loss for Scheduler: 0.5542
# saving model
# Epoch [50/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6035
# Validation: Avg Validation Loss: 0.5269
# Validation Loss for Scheduler: 0.5269
# saving model
# Epoch [51/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5933
# Validation: Avg Validation Loss: 0.5461
# Validation Loss for Scheduler: 0.5461
# saving model
# Epoch [52/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5858
# Validation: Avg Validation Loss: 0.5260
# Validation Loss for Scheduler: 0.5260
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5720
# Validation: Avg Validation Loss: 0.4977
# Validation Loss for Scheduler: 0.4977
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5708
# Validation: Avg Validation Loss: 0.5216
# Validation Loss for Scheduler: 0.5216
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5578
# Validation: Avg Validation Loss: 0.4818
# Validation Loss for Scheduler: 0.4818
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5473
# Validation: Avg Validation Loss: 0.4963
# Validation Loss for Scheduler: 0.4963
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5427
# Validation: Avg Validation Loss: 0.4994
# Validation Loss for Scheduler: 0.4994
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5394
# Validation: Avg Validation Loss: 0.4598
# Validation Loss for Scheduler: 0.4598
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5293
# Validation: Avg Validation Loss: 0.4462
# Validation Loss for Scheduler: 0.4462
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5288
# Validation: Avg Validation Loss: 0.4636
# Validation Loss for Scheduler: 0.4636
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5215
# Validation: Avg Validation Loss: 0.4520
# Validation Loss for Scheduler: 0.4520
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5151
# Validation: Avg Validation Loss: 0.4541
# Validation Loss for Scheduler: 0.4541
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5140
# Validation: Avg Validation Loss: 0.4371
# Validation Loss for Scheduler: 0.4371
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4997
# Validation: Avg Validation Loss: 0.4412
# Validation Loss for Scheduler: 0.4412
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4909
# Validation: Avg Validation Loss: 0.4649
# Validation Loss for Scheduler: 0.4649
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4895
# Validation: Avg Validation Loss: 0.4271
# Validation Loss for Scheduler: 0.4271
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4842
# Validation: Avg Validation Loss: 0.4341
# Validation Loss for Scheduler: 0.4341
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4797
# Validation: Avg Validation Loss: 0.4188
# Validation Loss for Scheduler: 0.4188
# saving model
# Epoch [69/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4728
# Validation: Avg Validation Loss: 0.4184
# Validation Loss for Scheduler: 0.4184
# saving model
# Epoch [70/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4685
# Validation: Avg Validation Loss: 0.4063
# Validation Loss for Scheduler: 0.4063
# saving model
# Epoch [71/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4690
# Validation: Avg Validation Loss: 0.4030
# Validation Loss for Scheduler: 0.4030
# saving model
# Epoch [72/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4581
# Validation: Avg Validation Loss: 0.4186
# Validation Loss for Scheduler: 0.4186
# saving model
# Epoch [73/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4525
# Validation: Avg Validation Loss: 0.3945
# Validation Loss for Scheduler: 0.3945
# saving model
# Epoch [74/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4472
# Validation: Avg Validation Loss: 0.3891
# Validation Loss for Scheduler: 0.3891
# saving model
# Epoch [75/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4485
# Validation: Avg Validation Loss: 0.3891
# Validation Loss for Scheduler: 0.3891
# saving model
# Epoch [76/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4450
# Validation: Avg Validation Loss: 0.3890
# Validation Loss for Scheduler: 0.3890
# saving model
# Epoch [77/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4439
# Validation: Avg Validation Loss: 0.3922
# Validation Loss for Scheduler: 0.3922
# saving model
# Epoch [78/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4381
# Validation: Avg Validation Loss: 0.3765
# Validation Loss for Scheduler: 0.3765
# saving model
# Epoch [79/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4353
# Validation: Avg Validation Loss: 0.3607
# Validation Loss for Scheduler: 0.3607
# saving model
# Epoch [80/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4262
# Validation: Avg Validation Loss: 0.3679
# Validation Loss for Scheduler: 0.3679
# saving model
# Epoch [81/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4260
# Validation: Avg Validation Loss: 0.3904
# Validation Loss for Scheduler: 0.3904
# saving model
# Epoch [82/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4271
# Validation: Avg Validation Loss: 0.3501
# Validation Loss for Scheduler: 0.3501
# saving model
# Epoch [83/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4176
# Validation: Avg Validation Loss: 0.3436
# Validation Loss for Scheduler: 0.3436
# saving model
# Epoch [84/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4192
# Validation: Avg Validation Loss: 0.3491
# Validation Loss for Scheduler: 0.3491
# saving model
# Epoch [85/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4131
# Validation: Avg Validation Loss: 0.3616
# Validation Loss for Scheduler: 0.3616
# saving model
# Epoch [86/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4117
# Validation: Avg Validation Loss: 0.3482
# Validation Loss for Scheduler: 0.3482
# saving model
# Epoch [87/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4172
# Validation: Avg Validation Loss: 0.3450
# Validation Loss for Scheduler: 0.3450
# saving model
# Epoch [88/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4066
# Validation: Avg Validation Loss: 0.3464
# Validation Loss for Scheduler: 0.3464
# saving model
# Epoch [89/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4029
# Validation: Avg Validation Loss: 0.3274
# Validation Loss for Scheduler: 0.3274
# saving model
# Epoch [90/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4040
# Validation: Avg Validation Loss: 0.3324
# Validation Loss for Scheduler: 0.3324
# saving model
# Epoch [91/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3973
# Validation: Avg Validation Loss: 0.3442
# Validation Loss for Scheduler: 0.3442
# saving model
# Epoch [92/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4012
# Validation: Avg Validation Loss: 0.3336
# Validation Loss for Scheduler: 0.3336
# saving model
# Epoch [93/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4018
# Validation: Avg Validation Loss: 0.3428
# Validation Loss for Scheduler: 0.3428
# saving model
# Epoch [94/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3891
# Validation: Avg Validation Loss: 0.3265
# Validation Loss for Scheduler: 0.3265
# saving model
# Epoch [95/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3917
# Validation: Avg Validation Loss: 0.3205
# Validation Loss for Scheduler: 0.3205
# saving model
# Epoch [96/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3928
# Validation: Avg Validation Loss: 0.3248
# Validation Loss for Scheduler: 0.3248
# saving model
# Epoch [97/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3883
# Validation: Avg Validation Loss: 0.3298
# Validation Loss for Scheduler: 0.3298
# saving model
# Epoch [98/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3908
# Validation: Avg Validation Loss: 0.3028
# Validation Loss for Scheduler: 0.3028
# saving model
# Epoch [99/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3878
# Validation: Avg Validation Loss: 0.3282
# Validation Loss for Scheduler: 0.3282
# saving model
# Epoch [100/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3870
# Validation: Avg Validation Loss: 0.3164
# Validation Loss for Scheduler: 0.3164
# saving model
# Training complete.
# Model saved to path: ../../../../../../models/Helpdesk/clean/Helpdesk_C_LSTM_v1_clean.pkl
# ([2.72735420060814,
#   2.6313670162760885,
#   2.5375806213518897,
#   2.4412199007261783,
#   2.3403396890797747,
#   2.246573367250075,
#   2.143851199281325,
#   2.039250357435384,
#   1.9342272303519992,
#   1.8239840236278848,
#   1.7218442685013517,
#   1.6265706173870542,
#   1.53213528427509,
#   1.4590021973356195,
#   1.3757451685196762,
#   1.3080227916393805,
#   1.2588859933231948,
#   1.19884488287322,
#   1.1533980861716313,
#   1.1161106130398741,
#   1.0816720007756435,
#   1.0472001887242728,
#   1.0122308386575192,
#   0.9841612703209623,
#   0.9666858960729127,
#   0.940079956426533,
#   0.9168366456250532,
#   0.8979588101763244,
#   0.8824807607799495,
#   0.8577251674932077,
#   0.8506280019742634,
#   0.8212641346345254,
#   0.8027340050684203,
#   0.791539790706897,
#   0.7814708748541841,
#   0.7613453104955341,
#   0.7456545605571991,
#   0.7394001601486031,
#   0.7203287225250804,
#   0.701931168590117,
#   0.7048066909160089,
#   0.6820376758728552,
#   0.6809780901178307,
#   0.6725337611972739,
#   0.6543877499366025,
#   0.6386541765217387,
#   0.6358883137549829,
#   0.6180517922300811,
#   0.610066709715292,
#   0.6035080709315221,
#   0.5932785004650781,
#   0.5858439324645821,
#   0.571984656770295,
#   0.5708167145558454,
#   0.5577722582795205,
#   0.5472696562972638,
#   0.5426760246174052,
#   0.5393910249438855,
#   0.5293090711219595,
#   0.5288386927285326,
#   0.5215454981961382,
#   0.5151007712707607,
#   0.5139738070445323,
#   0.49969174706060954,
#   0.4909123354548708,
#   0.4894796425322874,
#   0.4841626019926246,
#   0.4797132406212868,
#   0.47282177168841755,
#   0.46850258029928993,
#   0.46896115587938814,
#   0.458134000317766,
#   0.45253555175908117,
#   0.4471872772918929,
#   0.4484628924262633,
#   0.44501617933632037,
#   0.44391360974639926,
#   0.43813373934511746,
#   0.4353034413599093,
#   0.42620335560326184,
#   0.4260067052524024,
#   0.4270667372220153,
#   0.41759793009233037,
#   0.4191567056359501,
#   0.4131459396913511,
#   0.4116796789639587,
#   0.41724947764786013,
#   0.4066240450521128,
#   0.4028570412085691,
#   0.40399962738839856,
#   0.3973067255878667,
#   0.4011759077873799,
#   0.40182504495349497,
#   0.38912750896784143,
#   0.3916817297902676,
#   0.39275207787478733,
#   0.38831185426460496,
#   0.39083314133346625,
#   0.38776618211504515,
#   0.38698318279391036],
#  [2.6686408615112303,
#   2.471241749249972,
#   2.4726594352722167,
#   2.3740603637695314,
#   2.2695335578918456,
#   2.08067197066087,
#   2.0541013860702515,
#   1.9557859706878662,
#   1.7689020541998057,
#   1.7354407167434693,
#   1.6374642658233642,
#   1.4704921062176044,
#   1.4362252569198608,
#   1.3226708586399372,
#   1.2905308508872986,
#   1.2183717918395995,
#   1.1628523193872893,
#   1.1268310999870301,
#   1.0807601070404054,
#   1.0220626088289113,
#   1.0071486473083495,
#   0.9824335360527039,
#   0.9438051342964172,
#   0.9235987567901611,
#   0.8561870020169479,
#   0.8350553317711904,
#   0.8477644634246826,
#   0.8141386142143836,
#   0.7794089271472051,
#   0.7855670785903931,
#   0.761395180454621,
#   0.7693310746779809,
#   0.7210234254598618,
#   0.7425891661643982,
#   0.7107552218437195,
#   0.7180905525500958,
#   0.6947745776176453,
#   0.6437412981803601,
#   0.6365564924020034,
#   0.6575691843032837,
#   0.6317682361602783,
#   0.6258945477008819,
#   0.6272627246379853,
#   0.6254650819301605,
#   0.5882325804233551,
#   0.5657049956230017,
#   0.5802228260040283,
#   0.54254518866539,
#   0.5542488431930542,
#   0.5268901305703017,
#   0.5461172187328338,
#   0.5260020911693573,
#   0.4976630910084798,
#   0.5215718287688035,
#   0.4818439128307196,
#   0.4963482081890106,
#   0.4994345813989639,
#   0.45977640037353223,
#   0.4462333269990407,
#   0.46362482964992524,
#   0.4520452666282654,
#   0.4541428774595261,
#   0.43708917081356047,
#   0.4411824756860733,
#   0.46494910006339735,
#   0.42712807953357695,
#   0.43408486247062683,
#   0.4188114756345749,
#   0.41844684958457945,
#   0.4063081467151642,
#   0.403033122420311,
#   0.4186397853952188,
#   0.3945412945747375,
#   0.3890886989235878,
#   0.38907523214817047,
#   0.3889847635649718,
#   0.39223976492881774,
#   0.3764589994859237,
#   0.3607459091223203,
#   0.3678939604701904,
#   0.39041598558425905,
#   0.35009934925116026,
#   0.3436088143632962,
#   0.3491148020212467,
#   0.36164467692375185,
#   0.3482462243678478,
#   0.3449865860434679,
#   0.34635758221149443,
#   0.3274492615690598,
#   0.3324303546777138,
#   0.3441572406888008,
#   0.3335572600364685,
#   0.3428049811720848,
#   0.32646541053859085,
#   0.32048052535034144,
#   0.324830923974514,
#   0.32978479385375975,
#   0.30282364040613174,
#   0.3282180714607239,
#   0.3164256882782166])
