# %%
import importlib
import sys
import numpy as np
from collections import Counter
import pandas as pd

# performance imports for torch: torch kernel uses one core only.
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1" 

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %%
# Load the data
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../data/Helpdesk/tensor_data/normal/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../data/Helpdesk/tensor_data/normal/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)

# %%
# Helpdesk dataset dynamic categories, features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
# print(helpdesk_all_categories_cat)
helpdesk_all_categories_num = helpdesk_all_categories[1]
# print(helpdesk_all_categories_num)
for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk dynamic categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk dynamic numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
print('\n')
     
# Helpdesk dataset static categories, features:
helpdesk_all_stat_categories = helpdesk_train_dataset.all_static_categories

helpdesk_all_stat_categories_cat = helpdesk_all_stat_categories[0]
# print(helpdesk_all_stat_categories_cat)
helpdesk_all_stat_categories_num = helpdesk_all_stat_categories[1]
# print(helpdesk_all_stat_categories_num)
for i, cat in enumerate(helpdesk_all_stat_categories_cat):
     print(f"Helpdesk static categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(helpdesk_all_stat_categories_num):
     print(f"Helpdesk static numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk amount of numerical: {num[1]}")
# Out:
# Helpdesk dynamic categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk amount of category labels: 15
# Helpdesk dynamic categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk amount of category labels: 24
#
#
# Helpdesk dynamic numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: day_in_week, Index position in categorical data list: 2
# Helpdesk amount of numerical: 1
# Helpdesk dynamic numerical feature: seconds_in_day, Index position in categorical data list: 3
# Helpdesk amount of numerical: 1
#
#
# Helpdesk static categorical feature: VariantIndex, Index position in categorical data list: 0
# Helpdesk amount of category labels: 175
# Helpdesk static categorical feature: seriousness, Index position in categorical data list: 1
# Helpdesk amount of category labels: 2
# Helpdesk static categorical feature: customer, Index position in categorical data list: 2
# Helpdesk amount of category labels: 359
# Helpdesk static categorical feature: product, Index position in categorical data list: 3
# Helpdesk amount of category labels: 22
# Helpdesk static categorical feature: responsible_section, Index position in categorical data list: 4
# Helpdesk amount of category labels: 8
# Helpdesk static categorical feature: seriousness_2, Index position in categorical data list: 5
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_level, Index position in categorical data list: 6
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: service_type, Index position in categorical data list: 7
# Helpdesk amount of category labels: 5
# Helpdesk static categorical feature: support_section, Index position in categorical data list: 8
# Helpdesk amount of category labels: 7
# Helpdesk static categorical feature: workgroup, Index position in categorical data list: 9
# Helpdesk amount of category labels: 5

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)

# Encoder features (fixed): use only requested features
enc_feat_cat = ['Activity', 'Resource']
enc_feat_num = ['case_elapsed_time']
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Decoder features (unused by C-LSTM training cell, kept for consistency)
dec_feat_cat = ['Activity']
dec_feat_num = []
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time']]
# Features decoder:  [['Activity'], []]

# %%
import suffix_pred.models.C_LSTM
importlib.reload(suffix_pred.models.C_LSTM)
from suffix_pred.models.C_LSTM import FullShared_Join_LSTM

# Size hidden layer
hidden_size = 50

# Number of LSTM cells
num_layers = 1

# STANDARD: One numerical output to predict
input_size = 1

# C-LSTM uses dynamic prefix features only
model_feat = enc_feat

# Output size: activity classes only
activity_feature_name = 'Activity'
activity_feature_index = next(i for i, cat in enumerate(helpdesk_all_categories_cat) if cat[0] == activity_feature_name)
output_size_act = helpdesk_all_categories_cat[activity_feature_index][1]

# C-LSTM model initialization
model = FullShared_Join_LSTM(
    data_set_categories=helpdesk_all_categories,
    hidden_size=hidden_size,
    num_layers=num_layers,
    model_feat=model_feat,
    input_size=input_size,
    output_size_act=output_size_act,
)
# Out:
# Data set categories:  ([('Activity', 15, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'EOS': 4, 'INVALID': 5, 'Insert ticket': 6, 'RESOLVED': 7, 'Require upgrade': 8, 'Resolve SW anomaly': 9, 'Resolve ticket': 10, 'Schedule intervention': 11, 'Take in charge ticket': 12, 'VERIFIED': 13, 'Wait': 14}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Model input features:  [['Activity', 'Resource'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(15, 7)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size:  16
# Input feature size:  17
# Cells hidden size:  50
# Number of LSTM layer:  1
# /home/PSPLab/.local/share/virtualenvs/decision_aware_augmentation_for_PPM-0DzgvVpC/lib/python3.12/site-packages/torch/nn/modules/rnn.py:990: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)

# %%
import suffix_pred.loss
importlib.reload(suffix_pred.loss)
from suffix_pred.loss import Loss

loss_obj = Loss()

# %%
import suffix_pred.train
importlib.reload(suffix_pred.train)
from suffix_pred.train import CTraining

from torch.optim.lr_scheduler import ReduceLROnPlateau

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Start learning rate
learning_rate = 1e-5
weight_decay = 0.0

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15, min_lr=1e-8)

# Epochs / Batch size
num_epochs = 100
batch_size = 128

# Shuffle data
shuffle = True

optimize_values = {
    "optimizer": optimizer,
    "scheduler": scheduler,
    "epochs": num_epochs,
    "mini_batches": batch_size,
    "shuffle": shuffle,
}

# Activity feature index and EOS id for activity-only next-event prediction
activity_feature_name = 'Activity'
concept_name_id = next(i for i, cat in enumerate(helpdesk_all_categories_cat) if cat[0] == activity_feature_name)
activity_label_to_id = helpdesk_all_categories_cat[concept_name_id][2]
eos_id = activity_label_to_id.get('EOS')
if eos_id is None:
    raise ValueError("Could not find EOS id in activity label mapping.")

model_output_path = "Helpdesk_C_LSTM_v1.pkl"

trainer = CTraining(
    device=device,
    model=model,
    data_train=helpdesk_train_dataset,
    data_val=helpdesk_val_dataset,
    optimize_values=optimize_values,
    concept_name_id=concept_name_id,
    eos_id=eos_id,
    loss_obj=loss_obj,
    save_model_n_th_epoch=1,
    saving_path=model_output_path,
)

# Train the model (activity sequence modeling via next-activity training)
trainer.train()
# Out:
# Device: cuda
# Device:  cuda
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0.0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f2edd243200>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.6649
# Validation: Avg Validation Loss: 2.6336
# Validation Loss for Scheduler: 2.6336
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.5927
# Validation: Avg Validation Loss: 2.5551
# Validation Loss for Scheduler: 2.5551
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.5162
# Validation: Avg Validation Loss: 2.4769
# Validation Loss for Scheduler: 2.4769
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.4466
# Validation: Avg Validation Loss: 2.3962
# Validation Loss for Scheduler: 2.3962
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3681
# Validation: Avg Validation Loss: 2.2251
# Validation Loss for Scheduler: 2.2251
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2847
# Validation: Avg Validation Loss: 2.2207
# Validation Loss for Scheduler: 2.2207
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2105
# Validation: Avg Validation Loss: 2.1471
# Validation Loss for Scheduler: 2.1471
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1165
# Validation: Avg Validation Loss: 2.0304
# Validation Loss for Scheduler: 2.0304
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0299
# Validation: Avg Validation Loss: 1.8659
# Validation Loss for Scheduler: 1.8659
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9302
# Validation: Avg Validation Loss: 1.8640
# Validation Loss for Scheduler: 1.8640
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.8494
# Validation: Avg Validation Loss: 1.7575
# Validation Loss for Scheduler: 1.7575
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.7538
# Validation: Avg Validation Loss: 1.6434
# Validation Loss for Scheduler: 1.6434
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.6629
# Validation: Avg Validation Loss: 1.6058
# Validation Loss for Scheduler: 1.6058
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.5824
# Validation: Avg Validation Loss: 1.4927
# Validation Loss for Scheduler: 1.4927
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.4964
# Validation: Avg Validation Loss: 1.3942
# Validation Loss for Scheduler: 1.3942
# saving model
# Epoch [16/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.4284
# Validation: Avg Validation Loss: 1.3019
# Validation Loss for Scheduler: 1.3019
# saving model
# Epoch [17/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.3595
# Validation: Avg Validation Loss: 1.2477
# Validation Loss for Scheduler: 1.2477
# saving model
# Epoch [18/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.3144
# Validation: Avg Validation Loss: 1.2040
# Validation Loss for Scheduler: 1.2040
# saving model
# Epoch [19/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.2620
# Validation: Avg Validation Loss: 1.1206
# Validation Loss for Scheduler: 1.1206
# saving model
# Epoch [20/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.2139
# Validation: Avg Validation Loss: 1.1196
# Validation Loss for Scheduler: 1.1196
# saving model
# Epoch [21/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.1723
# Validation: Avg Validation Loss: 1.0979
# Validation Loss for Scheduler: 1.0979
# saving model
# Epoch [22/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.1349
# Validation: Avg Validation Loss: 1.0887
# Validation Loss for Scheduler: 1.0887
# saving model
# Epoch [23/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.1043
# Validation: Avg Validation Loss: 0.9851
# Validation Loss for Scheduler: 0.9851
# saving model
# Epoch [24/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.0686
# Validation: Avg Validation Loss: 0.9820
# Validation Loss for Scheduler: 0.9820
# saving model
# Epoch [25/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.0370
# Validation: Avg Validation Loss: 0.9609
# Validation Loss for Scheduler: 0.9609
# saving model
# Epoch [26/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.0065
# Validation: Avg Validation Loss: 0.9259
# Validation Loss for Scheduler: 0.9259
# saving model
# Epoch [27/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9815
# Validation: Avg Validation Loss: 0.9065
# Validation Loss for Scheduler: 0.9065
# saving model
# Epoch [28/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9508
# Validation: Avg Validation Loss: 0.9204
# Validation Loss for Scheduler: 0.9204
# saving model
# Epoch [29/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9338
# Validation: Avg Validation Loss: 0.8462
# Validation Loss for Scheduler: 0.8462
# saving model
# Epoch [30/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.9041
# Validation: Avg Validation Loss: 0.8373
# Validation Loss for Scheduler: 0.8373
# saving model
# Epoch [31/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8827
# Validation: Avg Validation Loss: 0.7934
# Validation Loss for Scheduler: 0.7934
# saving model
# Epoch [32/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8648
# Validation: Avg Validation Loss: 0.7880
# Validation Loss for Scheduler: 0.7880
# saving model
# Epoch [33/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8501
# Validation: Avg Validation Loss: 0.7464
# Validation Loss for Scheduler: 0.7464
# saving model
# Epoch [34/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8213
# Validation: Avg Validation Loss: 0.7464
# Validation Loss for Scheduler: 0.7464
# saving model
# Epoch [35/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.8094
# Validation: Avg Validation Loss: 0.7420
# Validation Loss for Scheduler: 0.7420
# saving model
# Epoch [36/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7937
# Validation: Avg Validation Loss: 0.7000
# Validation Loss for Scheduler: 0.7000
# saving model
# Epoch [37/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7746
# Validation: Avg Validation Loss: 0.6748
# Validation Loss for Scheduler: 0.6748
# saving model
# Epoch [38/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7630
# Validation: Avg Validation Loss: 0.6657
# Validation Loss for Scheduler: 0.6657
# saving model
# Epoch [39/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7402
# Validation: Avg Validation Loss: 0.6606
# Validation Loss for Scheduler: 0.6606
# saving model
# Epoch [40/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7318
# Validation: Avg Validation Loss: 0.6453
# Validation Loss for Scheduler: 0.6453
# saving model
# Epoch [41/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7172
# Validation: Avg Validation Loss: 0.6033
# Validation Loss for Scheduler: 0.6033
# saving model
# Epoch [42/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.7027
# Validation: Avg Validation Loss: 0.6247
# Validation Loss for Scheduler: 0.6247
# saving model
# Epoch [43/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6870
# Validation: Avg Validation Loss: 0.6270
# Validation Loss for Scheduler: 0.6270
# saving model
# Epoch [44/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6777
# Validation: Avg Validation Loss: 0.5756
# Validation Loss for Scheduler: 0.5756
# saving model
# Epoch [45/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6548
# Validation: Avg Validation Loss: 0.5974
# Validation Loss for Scheduler: 0.5974
# saving model
# Epoch [46/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6461
# Validation: Avg Validation Loss: 0.5843
# Validation Loss for Scheduler: 0.5843
# saving model
# Epoch [47/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6358
# Validation: Avg Validation Loss: 0.5500
# Validation Loss for Scheduler: 0.5500
# saving model
# Epoch [48/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6289
# Validation: Avg Validation Loss: 0.5518
# Validation Loss for Scheduler: 0.5518
# saving model
# Epoch [49/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6237
# Validation: Avg Validation Loss: 0.5627
# Validation Loss for Scheduler: 0.5627
# saving model
# Epoch [50/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.6099
# Validation: Avg Validation Loss: 0.5281
# Validation Loss for Scheduler: 0.5281
# saving model
# Epoch [51/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5942
# Validation: Avg Validation Loss: 0.5019
# Validation Loss for Scheduler: 0.5019
# saving model
# Epoch [52/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5817
# Validation: Avg Validation Loss: 0.5221
# Validation Loss for Scheduler: 0.5221
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5751
# Validation: Avg Validation Loss: 0.4715
# Validation Loss for Scheduler: 0.4715
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5612
# Validation: Avg Validation Loss: 0.4645
# Validation Loss for Scheduler: 0.4645
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5566
# Validation: Avg Validation Loss: 0.4788
# Validation Loss for Scheduler: 0.4788
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5459
# Validation: Avg Validation Loss: 0.4729
# Validation Loss for Scheduler: 0.4729
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5363
# Validation: Avg Validation Loss: 0.4674
# Validation Loss for Scheduler: 0.4674
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5260
# Validation: Avg Validation Loss: 0.4517
# Validation Loss for Scheduler: 0.4517
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5265
# Validation: Avg Validation Loss: 0.4441
# Validation Loss for Scheduler: 0.4441
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5148
# Validation: Avg Validation Loss: 0.4487
# Validation Loss for Scheduler: 0.4487
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5121
# Validation: Avg Validation Loss: 0.4275
# Validation Loss for Scheduler: 0.4275
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.5002
# Validation: Avg Validation Loss: 0.4069
# Validation Loss for Scheduler: 0.4069
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4926
# Validation: Avg Validation Loss: 0.4146
# Validation Loss for Scheduler: 0.4146
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4898
# Validation: Avg Validation Loss: 0.4099
# Validation Loss for Scheduler: 0.4099
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4812
# Validation: Avg Validation Loss: 0.4171
# Validation Loss for Scheduler: 0.4171
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4688
# Validation: Avg Validation Loss: 0.3937
# Validation Loss for Scheduler: 0.3937
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4708
# Validation: Avg Validation Loss: 0.3943
# Validation Loss for Scheduler: 0.3943
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4709
# Validation: Avg Validation Loss: 0.3835
# Validation Loss for Scheduler: 0.3835
# saving model
# Epoch [69/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4592
# Validation: Avg Validation Loss: 0.3906
# Validation Loss for Scheduler: 0.3906
# saving model
# Epoch [70/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4488
# Validation: Avg Validation Loss: 0.3862
# Validation Loss for Scheduler: 0.3862
# saving model
# Epoch [71/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4450
# Validation: Avg Validation Loss: 0.3855
# Validation Loss for Scheduler: 0.3855
# saving model
# Epoch [72/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4472
# Validation: Avg Validation Loss: 0.3637
# Validation Loss for Scheduler: 0.3637
# saving model
# Epoch [73/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4452
# Validation: Avg Validation Loss: 0.3733
# Validation Loss for Scheduler: 0.3733
# saving model
# Epoch [74/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4375
# Validation: Avg Validation Loss: 0.3586
# Validation Loss for Scheduler: 0.3586
# saving model
# Epoch [75/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4237
# Validation: Avg Validation Loss: 0.3665
# Validation Loss for Scheduler: 0.3665
# saving model
# Epoch [76/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4239
# Validation: Avg Validation Loss: 0.3394
# Validation Loss for Scheduler: 0.3394
# saving model
# Epoch [77/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4206
# Validation: Avg Validation Loss: 0.3399
# Validation Loss for Scheduler: 0.3399
# saving model
# Epoch [78/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4201
# Validation: Avg Validation Loss: 0.3622
# Validation Loss for Scheduler: 0.3622
# saving model
# Epoch [79/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4194
# Validation: Avg Validation Loss: 0.3384
# Validation Loss for Scheduler: 0.3384
# saving model
# Epoch [80/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4128
# Validation: Avg Validation Loss: 0.3395
# Validation Loss for Scheduler: 0.3395
# saving model
# Epoch [81/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4193
# Validation: Avg Validation Loss: 0.3272
# Validation Loss for Scheduler: 0.3272
# saving model
# Epoch [82/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4007
# Validation: Avg Validation Loss: 0.3276
# Validation Loss for Scheduler: 0.3276
# saving model
# Epoch [83/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3973
# Validation: Avg Validation Loss: 0.3307
# Validation Loss for Scheduler: 0.3307
# saving model
# Epoch [84/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4039
# Validation: Avg Validation Loss: 0.3291
# Validation Loss for Scheduler: 0.3291
# saving model
# Epoch [85/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3945
# Validation: Avg Validation Loss: 0.3225
# Validation Loss for Scheduler: 0.3225
# saving model
# Epoch [86/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.4012
# Validation: Avg Validation Loss: 0.3310
# Validation Loss for Scheduler: 0.3310
# saving model
# Epoch [87/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3921
# Validation: Avg Validation Loss: 0.3177
# Validation Loss for Scheduler: 0.3177
# saving model
# Epoch [88/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3912
# Validation: Avg Validation Loss: 0.3075
# Validation Loss for Scheduler: 0.3075
# saving model
# Epoch [89/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3852
# Validation: Avg Validation Loss: 0.3140
# Validation Loss for Scheduler: 0.3140
# saving model
# Epoch [90/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3896
# Validation: Avg Validation Loss: 0.3044
# Validation Loss for Scheduler: 0.3044
# saving model
# Epoch [91/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3784
# Validation: Avg Validation Loss: 0.2967
# Validation Loss for Scheduler: 0.2967
# saving model
# Epoch [92/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3755
# Validation: Avg Validation Loss: 0.2972
# Validation Loss for Scheduler: 0.2972
# saving model
# Epoch [93/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3776
# Validation: Avg Validation Loss: 0.2966
# Validation Loss for Scheduler: 0.2966
# saving model
# Epoch [94/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3799
# Validation: Avg Validation Loss: 0.3173
# Validation Loss for Scheduler: 0.3173
# saving model
# Epoch [95/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3692
# Validation: Avg Validation Loss: 0.2982
# Validation Loss for Scheduler: 0.2982
# saving model
# Epoch [96/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3724
# Validation: Avg Validation Loss: 0.2981
# Validation Loss for Scheduler: 0.2981
# saving model
# Epoch [97/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3712
# Validation: Avg Validation Loss: 0.2984
# Validation Loss for Scheduler: 0.2984
# saving model
# Epoch [98/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3710
# Validation: Avg Validation Loss: 0.2821
# Validation Loss for Scheduler: 0.2821
# saving model
# Epoch [99/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3662
# Validation: Avg Validation Loss: 0.2957
# Validation Loss for Scheduler: 0.2957
# saving model
# Epoch [100/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 0.3573
# Validation: Avg Validation Loss: 0.2879
# Validation Loss for Scheduler: 0.2879
# saving model
# Training complete.
# Model saved to path: Helpdesk_C_LSTM_v1.pkl
# ([2.6649409368497516,
#   2.592658843469182,
#   2.516195994998337,
#   2.4466183448056564,
#   2.3681072926302567,
#   2.284677883900634,
#   2.2105394678378323,
#   2.1164892813481324,
#   2.0298562902923023,
#   1.9301996734164177,
#   1.8494051924539268,
#   1.753842656765509,
#   1.6628711420461673,
#   1.5824218747812673,
#   1.496448214994658,
#   1.428386300528815,
#   1.3594584284572426,
#   1.3144060466267646,
#   1.261981491101991,
#   1.2139485861183306,
#   1.1723168344672668,
#   1.1348798280462213,
#   1.1042965415420882,
#   1.0685805153409276,
#   1.036982341643867,
#   1.0064597873512757,
#   0.9815381221268156,
#   0.9507977098499963,
#   0.9337596890576388,
#   0.9040835652876338,
#   0.8827498910623953,
#   0.864794386089395,
#   0.8500834271448467,
#   0.8212947897407987,
#   0.8093806751277468,
#   0.7937334456028194,
#   0.7745884848297189,
#   0.7629515725538272,
#   0.7402434365465007,
#   0.7317807912279707,
#   0.7172458199186063,
#   0.7027469572670962,
#   0.6869829154889519,
#   0.6776588578289802,
#   0.6548452913214308,
#   0.6461059535862109,
#   0.6358360534687655,
#   0.6289017501227353,
#   0.6236932767093728,
#   0.6098617886731384,
#   0.5941741325713079,
#   0.5816864860714028,
#   0.5751363641898567,
#   0.561158569580918,
#   0.5566070310839819,
#   0.5458669216807829,
#   0.5363113385274869,
#   0.5259887484508917,
#   0.5265167490878236,
#   0.514785731467632,
#   0.5121135602303601,
#   0.5001933920547503,
#   0.49256653495884817,
#   0.489791582620472,
#   0.48124525743886964,
#   0.4688243272654507,
#   0.47078589288466566,
#   0.4708867388854333,
#   0.45915549952502643,
#   0.4488071408977202,
#   0.44500693596831153,
#   0.447233149286257,
#   0.4451851761395778,
#   0.4375450631620687,
#   0.4237303856862794,
#   0.42385152597492987,
#   0.4206119310965232,
#   0.420110394238332,
#   0.41936760231715825,
#   0.4128128656553566,
#   0.4193474455574237,
#   0.4007380555529113,
#   0.3973180573057691,
#   0.40389165466805116,
#   0.3944790009238304,
#   0.40122441339110015,
#   0.392137063137435,
#   0.39115222153860496,
#   0.3852486445679577,
#   0.3896421805160855,
#   0.3784008354222009,
#   0.3754723813692364,
#   0.37758674752821614,
#   0.379874236745025,
#   0.3691988700163474,
#   0.3724188848372993,
#   0.3712133215654881,
#   0.3710263279189757,
#   0.36621885411783095,
#   0.3573014112787509],
#  [2.6336312770843504,
#   2.5551085662841797,
#   2.4769251441955564,
#   2.39615948677063,
#   2.22514754992265,
#   2.2207111167907714,
#   2.1470859050750732,
#   2.030444461565751,
#   1.8658583531012902,
#   1.863973741531372,
#   1.7575309038162232,
#   1.6434084956462567,
#   1.605833269082583,
#   1.492722086906433,
#   1.394170985221863,
#   1.3018748622674208,
#   1.2476500524924352,
#   1.204016965169173,
#   1.1206084421047797,
#   1.1196354246139526,
#   1.0978655087947846,
#   1.0886620718699236,
#   0.9850761867486514,
#   0.9819602680206299,
#   0.9609321737289429,
#   0.9258915865421296,
#   0.9065021753311158,
#   0.9204053764159863,
#   0.8462468600273132,
#   0.837330985069275,
#   0.793382296195397,
#   0.788026077747345,
#   0.7463547942730097,
#   0.746369000673294,
#   0.7419705092906952,
#   0.699964138177725,
#   0.6747822910547256,
#   0.6656947405292437,
#   0.6606474173069,
#   0.6452882766723633,
#   0.6032659789690604,
#   0.6247498750686645,
#   0.6270116258126038,
#   0.5756007438668838,
#   0.5974307668209076,
#   0.5842534637451172,
#   0.5499679784362133,
#   0.5517998313903809,
#   0.562707531452179,
#   0.5281338500976562,
#   0.5018878166492169,
#   0.5220636689662933,
#   0.471513369335578,
#   0.46446165213218105,
#   0.4788297641277313,
#   0.4728625160455704,
#   0.46742830336093905,
#   0.4516614887576837,
#   0.44413297235965726,
#   0.4487340843677521,
#   0.42746460838959766,
#   0.4068704304786829,
#   0.4145682889223099,
#   0.4099152237176895,
#   0.41707782685756684,
#   0.39367161214351654,
#   0.3942998212575912,
#   0.38348415315151213,
#   0.3905704915523529,
#   0.38616682946681974,
#   0.38548876225948336,
#   0.3637383818626404,
#   0.37325524985790254,
#   0.35864314895409805,
#   0.3665423575043678,
#   0.33936267690016675,
#   0.3399334987998009,
#   0.3622307673096657,
#   0.3383741280436516,
#   0.3394939774274826,
#   0.3271735728933261,
#   0.3276288715692667,
#   0.3306599190831184,
#   0.32907683373643803,
#   0.3224952149391174,
#   0.33100060403347015,
#   0.31771841645240784,
#   0.3074839010834694,
#   0.3140046429634094,
#   0.30442635640501975,
#   0.29673025527825725,
#   0.297225201359162,
#   0.2966492013432659,
#   0.3172704938054085,
#   0.29823077023029326,
#   0.298130292731982,
#   0.29836620777845385,
#   0.28206090457164323,
#   0.29568700850009916,
#   0.28788610398769376])
